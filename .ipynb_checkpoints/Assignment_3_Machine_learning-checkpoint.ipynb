# %% [markdown]
# **Aman Oberoi
# St125490**

# %%
import numpy as np
import pandas as pd
import os
import mlflow
#tried to trun the auto long off
mlflow.autolog(disable=True)
pd.set_option('compute.use_numexpr', True)

import seaborn as sns
import matplotlib.pyplot as plt
from ipywidgets import widgets, interactive
import missingno as msno 

from sklearn import preprocessing
from sklearn.metrics import mean_squared_log_error, mean_squared_error
from sklearn.model_selection import KFold
from sklearn.preprocessing import OrdinalEncoder, StandardScaler, MinMaxScaler, PolynomialFeatures, OneHotEncoder
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, precision_score, recall_score, confusion_matrix
from cf_matrix import make_confusion_matrix

from Models.Logistic_regression import LogisticRegression
#all the imports


import warnings
warnings.filterwarnings('ignore')

# %%
mlflow.set_tracking_uri("http://localhost:5000")
#while deployment change the name from qb
os.environ["LOGNAME"] = "qb"

# %%
x_data = pd.read_csv('./data/Cars.csv')
x_data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %%
# x_data['owner']=x_data['owner'].astype('category')
x_data['seller_type'].value_counts()
# Out:
# seller_type
# Individual          6766
# Dealer              1126
# Trustmark Dealer     236
# Name: count, dtype: int64

# %% [markdown]
# **Tried to combine Dealer and Truestmaker Dealer as group**

# %%
x_data['owner'].loc[x_data[(x_data['owner'] == 'Fourth & Above Owner') | (x_data['owner'] == 'Third Owner')].index] = 'others'

# %%
#few operations
#remove the rows with CNG and Petrol because of diffenece in units
x_data.drop(x_data[(x_data['fuel'] == 'CNG') | (x_data['fuel'] == 'LPG')].index, inplace=True)
x_data['mileage']=x_data['mileage'].apply(lambda x: str(x).split()[0]).astype('float')
x_data['engine'] = x_data['engine'].apply(lambda x: str(x).split()[0]).astype('float')

#remove the torque
x_data.drop(columns = {'torque'}, inplace=True)
# remove the test drive owners
x_data.drop(x_data[x_data['owner']=='Test Drive Car'].index, inplace=True)
x_data['company'] = x_data['name'].apply(lambda x:  x.split()[0])

x_data['max_power']= x_data['max_power'].apply(lambda x: str(x).split()[0])
x_data['max_power'] = x_data['max_power'].replace('bhp', np.NAN).astype('float')

# %%
#the number of companies car sold in total 
#this could be a feature to explain the future trajectory in the data
c_per_company =x_data['name'].apply(lambda x:x.split()[0]).value_counts()
sns.barplot(data = c_per_company.to_frame().reset_index(), x = 'count', y = 'name')
# sns.barplot(data = c_per_company.reset_index(name='count').rename(columns = {'index':'names'}), x = 'count', y = 'names')
# Out:
# <Axes: xlabel='count', ylabel='name'>

# %% [markdown]
# **Number of indivisual cars sold by the companies, though this is just and Explaination of Data might not condiser as feature**

# %%
x_data['km_distances']=x_data.groupby(['company','year','owner'])['km_driven'].transform(lambda x:  x.mean())

x_data['log_selling_price'] = x_data['selling_price'].transform('log')
x_data['log_km_distances'] = x_data['km_distances'].transform('log')
sns.scatterplot(data = x_data, x = 'log_km_distances', y = 'log_selling_price', hue="owner")

x_data.drop(columns = {'log_selling_price', 'log_km_distances'}, inplace=True)
#(np.log(x_data['selling_price']), np.log(x_data['km_distances']), hue='owner')

# %% [markdown]
# **As the more the car is driven, the lesser the price**

# %%
#the specific company is almost null
x_data.drop(6730, inplace=True)

# %% [markdown]
# **Droping the row 6730 as it is almost misisng**

# %%
ax=sns.boxplot(data = x_data, x = 'owner', y = x_data['selling_price'].transform('log'))
v=ax.set_xticklabels(ax.get_xticklabels(),rotation=45)

# %% [markdown]
# <span style = 'color:black'>**The First Owner has the considerable effect on the selling price owners with lesser driven and are from specific category of owner has the effect.**</span>

# %%
ax=sns.boxplot(data = x_data,x = 'company', y = 'selling_price')
v=ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %%
b = x_data[['company', 'year', 'selling_price']].groupby(['company', 'year'])['selling_price'].apply(lambda x: x.sum())
b=b.reset_index()
sns.heatmap(b.pivot(columns = 'company', index = 'year', values = 'selling_price'))
#for example the maruti company have less selling price in 1983 than in 2020 but at the same time maruti have shown in the number of selling price
# Out:
# <Axes: xlabel='company', ylabel='year'>

# %% [markdown]
# **Maruti has very less variation in selling price, yet is the most sold car accross the year, so the selling of maruti car is constant because of the range of price is not varying with the given data. At the same time BMW has the sqwness in bounding box feature sample is very less**

# %%
#average sale of the company per year 
r=x_data.groupby(['company', 'year'])['name'].apply(lambda x:x.count()).reset_index()

r.set_index('year', inplace=True)
#r[r['company'] == 'Maruti']['name'].plot()
#x_data['company'].unique().shape
company_name = []
n_ = r['company'].value_counts().reset_index()
for k,i in n_.iterrows():
    if i['count'] > 6:
        company_name.append(i['company'])
Company_name = widgets.Dropdown(options= company_name, value=None, description='Company Name:')
def vol_plt(Company_name):
    df2 = r.copy()
    df2 = df2[df2.company == Company_name]
    if len(df2) > 0:
        #pv_df =x.pivot(index='time_id', columns='stock_id', values='target')
        df2.plot()
        plt.show()

interactive(vol_plt,Company_name=Company_name)
# Out:
# interactive(children=(Dropdown(description='Company Name:', options=('Maruti', 'Mahindra', 'Hyundai', 'Tata', …

# %% [markdown]
# **pre company car soled select the drop box**

# %%
# r = x_data[(x_data['company'] == 'Maruti') & (x_data['year'] == 2014)]
# r[['company', 'name', 'year', 'selling_price']].groupby(['name', 'year'])['selling_price'].apply(lambda x: x.sum())

# %%
#log transfrom of training data
# x_data['selling_price'] = x_data['selling_price'].transform('log')

# %%
lb= OrdinalEncoder()
t = lb.fit(x_data['transmission'].values.reshape(-1,1))
# with open('transmission.pickle', 'wb') as f:
#     pickle.dump(t, f)

# %%
lb= OneHotEncoder()
f = lb.fit(x_data['fuel'].values.reshape(-1, 1))
# with open('fuel.pickle', 'wb') as f_:
#     pickle.dump(f, f_)

# %%
lb= OrdinalEncoder()
o = lb.fit(x_data['company'].values.reshape(-1,1))
# with open('company.pickle', 'wb') as f:
#     pickle.dump(o, f)

# %%
lb = OneHotEncoder()
b = lb.fit(x_data['owner'].values.reshape(-1, 1))
# with open('owner.pickle', 'wb') as f:
#     pickle.dump(b, f)

# %%
lb = OrdinalEncoder()
b_ = lb.fit(x_data['owner'].values.reshape(-1, 1))
# with open('owner_ordinal.pickle', 'wb') as f:
#     pickle.dump(b, f)

# %% [markdown]
# **Few embedding done**

# %% [markdown]
# **<span style="color:blue">Binning Classes</span>**

# %%
import more_itertools
x_data['binned_selling_price'] = 0
quantiles = [x_data['selling_price'].quantile(0), x_data['selling_price'].quantile(0.25), x_data['selling_price'].quantile(0.50), x_data['selling_price'].quantile(0.75), x_data['selling_price'].quantile(1.)]
quantiles =list(more_itertools.windowed(quantiles,2))
index_ = x_data.index.to_list()
res = {'c':[], 'index':[]}
def cut_bin(x, quant):
    for i,q in enumerate(quantiles):
        if i != 3:
            idx=x['selling_price'][(x['selling_price'] >= quantiles[i][0]) & (x['selling_price'] <= quantiles[i][1]-10)].index
        else:
            idx=x['selling_price'][(x['selling_price'] >= quantiles[i][0]) & (x['selling_price'] <= quantiles[i][1])].index

        if idx.any():
            #x_data['binned_selling_price'] = n 
            res['c'].append(np.repeat(i, idx.shape[0]))
            res['index'].append(idx)
x_data.groupby('company')[['selling_price','binned_selling_price']].apply(lambda x: cut_bin(x, quantiles))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
x_data['binned_selling_price']=pd.DataFrame({
    'class':np.apply_along_axis(np.hstack,arr=res['c'],axis=0)},
        index = np.apply_along_axis(np.hstack, arr=res['index'], axis=0))

# %%
df1 = x_data.pivot_table(index = 'company', columns = 'binned_selling_price', values = 'selling_price', aggfunc = np.mean)

# %%
fig,ax =plt.subplots(1,2, figsize=(10,5))
ax=ax.flatten()
sns.heatmap(df1, ax=ax[0])
sns.histplot(x_data['binned_selling_price'], ax=ax[1])
plt.tight_layout()

# %% [markdown]
# **Binned distribution, each class like 0 and 2 has lower range of selling_price accross the cars distribution model.We did it this way inorder to reduce the bin bias and and out of sample classes if we split(ie train, test or validation) and bin**

# %% [markdown]
# **Early test train split at unifrom random**

# %%
#split the training and testing data before hand
x_data['index'] = x_data.index
# test = x_data.loc[round(x_data.shape[0]-x_data.shape[0]*0.20):x_data.shape[0]]
# train = x_data.loc[0:round(x_data.shape[0]-x_data.shape[0]*0.20) - 1]
state = round(np.random.uniform(100))
train, test, y_train, y_test = train_test_split(x_data, x_data['selling_price'], test_size=0.20, random_state= state)

# %%
train.shape, y_train.shape
# Out:
# ((6421, 16), (6421,))

# %%
number_sold = train.groupby(['company'])['name'].apply(lambda  x: x.value_counts()).to_frame().reset_index().rename(columns = {'level_1':'name', 'name':'number_sold'})
train = pd.merge(number_sold, train, on = ['company', 'name'], how = 'right')

number_sold = test.groupby(['company'])['name'].apply(lambda  x: x.value_counts()).to_frame().reset_index().rename(columns = {'level_1':'name', 'name':'number_sold'})
test = pd.merge(number_sold, test, on = ['company', 'name'], how = 'right')

# %% [markdown]
# **Let us see the impact of numbers of vayring car sold each year by the each company**

# %%
#because of short of time could make interactive plots
r2 = train.groupby(['company', 'name','year'])['selling_price'].apply(lambda x:x.mean()).reset_index()
r2[(r2['company'] == 'Maruti') & (r2['name'] == 'Maruti Ritz VDi')][['year','selling_price']].set_index('year').plot(title = 'Maruti Ritz VDi')
# Out:
# <Axes: title={'center': 'Maruti Ritz VDi'}, xlabel='year'>

# %%
msno.matrix(train)
# Out:
# <Axes: >

# %% [markdown]
# **The missingness looks like not missing at random. The missing data might have some pattren by some covariates
# or eaxtral causal impact, which out of the scope of this notebook, we did some basic imputation**

# %%
def imputation_d(x):
    if x.shape[0] > 0:            
        x['engine']=x['engine'].apply(lambda x: str(x).split()[0]).astype('float')
        x['index'] = x.index
        r=x.groupby('company')['engine'].apply(lambda x: x.fillna(x.median()))
        x.set_index(['company', 'index'], inplace=True)
        x['engine'] = r
        x.reset_index(inplace=True)
        
        #even though the full distribution is centered to mean but so mean is close to median , 
        #but here filling up each distribution with median as per the company
        # filling missing values for milage
        x['index'] = x.index
        r = x.groupby('company')['mileage'].apply(lambda x: x.fillna(x.mean()))
        x.set_index(['company', 'index'], inplace=True)
        x['mileage'] = r
        x.reset_index(inplace=True)
        
        x['binned_engine']=pd.cut(x['engine'], [1, 1000, 1500, 1800, x['engine'].max()], labels = list(range(1,5))[::-1])
        #drop all the na columns
        x.drop(x[x['binned_engine'].isna()].index, inplace=True)
        x['binned_engine'] = x.binned_engine.astype('int')
        
        #the distribution of max_power is not mean centered as whole so each group will be assumed (because the data is MNAR) to have median of each 
        #maxpower engine produced by companies
        x['index'] = x.index
        r = x.groupby('company')['max_power'].apply(lambda x: x.fillna(x.mean()))
        x.set_index(['company', 'index'], inplace=True)
        x['max_power'] = r
        x.reset_index(inplace=True)
        
        # seat is not the ordinal data if that so enconding required
        # filling na values by filling in with a company not sure if this make sense 
        ix=x[x['seats'].isna()].index
        for i in ix:
            name =x.loc[i]['company']
            min_seats = x[x['company'] == name]['seats'].min()
            max_seats = x[x['company'] == name]['seats'].max()
            if not pd.isna(min_seats):
                x['seats'].loc[i]=round(max_seats/min_seats) 
        return x

# %%
train = imputation_d(train)
test = imputation_d(test)

# %%
#binning
fig, ax=plt.subplots(2)
sns.scatterplot(ax = ax[0],data = train , x ='selling_price', y= 'mileage', hue = 'binned_engine', alpha=0.5)
bin_counts = train['binned_engine'].value_counts().reset_index()
sns.barplot(ax = ax[1], data = bin_counts, x= 'binned_engine', y = 'count')
# Out:
# <Axes: xlabel='binned_engine', ylabel='count'>

# %% [markdown]
# **Engine can be considered as ordinal data, because the better the engine by cc is the higher the price, we tries to perform ordinal linear encoding by binning the ranges of engines per cc**

# %%
def features(x, encoding='one_hot', phase='Traning', required_unscale = True):
    #x['avg_yearly'] = x.groupby(['company','year'])['selling_price'].transform('mean')
    x['co_cc']=x.groupby(['company'])['year'].transform(lambda x: sum(x-x.min())).astype('float')
    x['_num_sales'] = x.groupby(['company', 'year'])['name'].transform('count')
    r=x.groupby(['company', 'year'])['name'].apply(lambda x:x.count()).reset_index() 
        
    x['transmission'] = pd.Series(t.transform(x['transmission'].values.reshape(-1,1)).astype('int').flatten())
    
    m = f.transform(np.array(x['fuel']).reshape(-1,1)).toarray()
    x[['Diesel','petrol']] = pd.DataFrame.from_records(m , columns = x['fuel'].unique())

    if encoding == 'one_hot':
        m = b.transform(np.array(x['owner']).reshape(-1,1)).toarray()
        x[['firstowner', 'secondowner', 'others']] = pd.DataFrame.from_records(m, columns = x['owner'].unique())
    elif encoding == 'oridinal':
        x['_owner_encoded'] = pd.Series(b_.transform(x['owner'].values.reshape(-1,1)).astype('int').flatten())
#     x['_owner_encoded']=x.groupby('company')['_owner_encoded'].transform(lambda x: x/x.max())
    
    x['_company'] = o.transform(x['company'].values.reshape(-1,1)).astype('int')

    r = x.groupby(['company', 'year'])['seats'].value_counts()
    x.set_index(['company', 'year', 'seats'], inplace = True)
    x['_seats_in_year'] = r
    x.reset_index(inplace=True)
    
    r = x.groupby(['company', 'seller_type'])['selling_price'].apply(np.mean)
    x.set_index(['company', 'seller_type'], inplace=True)
    x['avg_sellertype'] = r
    x.reset_index(inplace=True)
    
###scaling features
    x['km_distances']=x.groupby(['company', 'year','owner'])['km_driven'].transform(lambda x: x.mean())
    x['km_distances'] = x['km_distances'].transform('log')
    
    global s_, s_p
    fs = ['km_distances', 'avg_sellertype', 'max_power','selling_price', 'mileage', 'engine', '_num_sales', '_seats_in_year']
    if phase =='Training':
        s = StandardScaler()
        selling_price = x['selling_price']
        s_ = s.fit(x[fs].values)
        x[fs] = s_.transform(x[fs].values)
        if required_unscale:
            s_1 = StandardScaler()
            s_p = s_1.fit(selling_price.values.reshape(-1, 1))
            return x, selling_price,s_p
    elif phase == 'Testing':
            selling_price = x['selling_price']
            x[fs] = s_.transform(x[fs].values)
            if required_unscale:
                return x, selling_price,s_p
    #per year sold cars 
    
    return x

# %% [markdown]
# **Basic Feature Engineering ,**
# * the older year model have lesser price than recent model accroding the data
# * Number of Sales by the company
# * One hot encoding of other features
# * Km distances the range as it travled, more or less
# * Few standard scaling
# **Tried more features but have impact on predictability**

# %%
train['selling_price'] = train['selling_price']
test['selling_price'] = test['selling_price']
train, unscaled_train, scaler_train  = features(train, phase='Training')
test, unscaled_test,scaler_test = features(test, phase='Testing')

# %%
x_target = train['selling_price']
y_target = test['selling_price']

# %%
train[['Diesel', 'petrol', 'firstowner', 'others', 'secondowner']] =train[['Diesel', 'petrol', 'firstowner', 'others','secondowner']].astype('int')

# %%
drop_columns = ['seats','owner',
                'seller_type','number_sold','name',
                'index', 'company', 'fuel', 'transmission', 'km_driven', 'selling_price','_seats_in_year','_company'
               ,'_num_sales','secondowner', 'co_cc', 'engine', 'year']
train.drop(columns = drop_columns, inplace=True)
test.drop(columns = drop_columns,inplace=True)
ax=train.hist()
feature_names = train.columns

# %%
train[train['binned_selling_price'].isna()]
#droping the na values at 2763 as it does only one class type and considered NAN
train.dropna(inplace=True)
test.dropna(inplace=True)

# %%
#convert into categorical if no support
train['binned_selling_price']=train['binned_selling_price'].astype('int')
test['binned_selling_price'] = test['binned_selling_price'].astype('int')
train_y = train['binned_selling_price']
test_y = test['binned_selling_price']
train.drop(columns = 'binned_selling_price', inplace =True)
test.drop(columns = 'binned_selling_price', inplace=True)

# %%
cols = ['Diesel', 'binned_engine', 'petrol', 'firstowner', 'others']
train[cols]=train[cols].astype('category')

# %%
#here train and test split have sufficent classes 
train_y_=pd.get_dummies(train_y)*1
test_y_ = pd.get_dummies(test_y)*1

# %%
model = LogisticRegression(4, train.shape[1], method="minibatch", l2= 0.01,batch_size=50, num_epochs=50)
model.fit(train.values,dummies=train_y_.values, Y= train_y.values)
# Out:
# Loss at iteratioin 1.9178200810850565
# Loss at iteratioin 1.7262984056493391
# Loss at iteratioin 1.4357077665733884
# Loss at iteratioin 1.441429381494466
# Loss at iteratioin 1.3584574076747162
# Loss at iteratioin 1.4164690859531575
# Loss at iteratioin 1.3854121205892556
# Loss at iteratioin 1.2748481900145339
# Loss at iteratioin 1.2974947036699769
# Loss at iteratioin 1.4242449962073294
# Loss at iteratioin 1.3574498964792916
# Loss at iteratioin 1.3434780306459675
# Loss at iteratioin 1.2031740269160016
# Loss at iteratioin 1.085427400840236
# Loss at iteratioin 1.277510847677318
# Loss at iteratioin 1.199313894797793
# Loss at iteratioin 1.245407692437326
# Loss at iteratioin 1.260012872646047
# Loss at iteratioin 1.1187066180835712
# Loss at iteratioin 1.183001960622586
# Loss at iteratioin 1.361417525546168
# Loss at iteratioin 1.2738973426777827
# Loss at iteratioin 1.2613907630659114
# Loss at iteratioin 1.1267339836479042
# Loss at iteratioin 1.0118870221738852
# Loss at iteratioin 1.2377795148662276
# Loss at iteratioin 1.1489376629507684
# Loss at iteratioin 1.188223603420333
# Loss at iteratioin 1.2127499433664386
# Loss at iteratioin 1.058623311283335
# Loss at iteratioin 1.138878119322435
# Loss at iteratioin 1.34410529748977
# Loss at iteratioin 1.2345784322813282
# Loss at iteratioin 1.2213324279890672
# Loss at iteratioin 1.0950663677541423
# Loss at iteratioin 0.9775117402889817
# Loss at iteratioin 1.220206457290369
# Loss at iteratioin 1.123884171405257
# Loss at iteratioin 1.1588054038245186
# Loss at iteratioin 1.1888534437730107
# Loss at iteratioin 1.0257190200466497
# Loss at iteratioin 1.115330209632572
# Loss at iteratioin 1.3388900735796365
# Loss at iteratioin 1.2110354380639636
# Loss at iteratioin 1.197473628503604
# Loss at iteratioin 1.0779245320428577
# Loss at iteratioin 0.9571960866023754
# Loss at iteratioin 1.210453131100432
# Loss at iteratioin 1.1088375315641426
# Loss at iteratioin 1.1407566046855047
# Loss at iteratioin 1.1751933966215895
# Loss at iteratioin 1.004667067090033
# Loss at iteratioin 1.1005845658818
# Loss at iteratioin 1.3380414254166093
# Loss at iteratioin 1.1952416627064615
# Loss at iteratioin 1.181708786849775
# Loss at iteratioin 1.0671676820418805
# Loss at iteratioin 0.9436011260976268
# Loss at iteratioin 1.2042707383273936
# Loss at iteratioin 1.098731618375059
# Loss at iteratioin 1.1285137557481155
# Loss at iteratioin 1.1668670270530064
# Loss at iteratioin 0.9899157127721053
# Loss at iteratioin 1.0903943993715373
# Loss at iteratioin 1.3389823769457532
# Loss at iteratioin 1.1839322393911786
# Loss at iteratioin 1.1705897492275643
# Loss at iteratioin 1.059717364886406
# Loss at iteratioin 0.9337707148088106
# Loss at iteratioin 1.1999815242721015
# Loss at iteratioin 1.0914058370135955
# Loss at iteratioin 1.1196114410070204
# Loss at iteratioin 1.1616183521220322
# Loss at iteratioin 0.9789272704808432
# Loss at iteratioin 1.0828506950902754
# Loss at iteratioin 1.3406636032248127
# Loss at iteratioin 1.1754846888259487
# Loss at iteratioin 1.162379051661676
# Loss at iteratioin 1.054162756092056
# Loss at iteratioin 0.9262706973856459
# Loss at iteratioin 1.1967972523656007
# Loss at iteratioin 1.085783915480752
# Loss at iteratioin 1.1127821357269732
# Loss at iteratioin 1.158268985311305
# Loss at iteratioin 0.9703686612867095
# Loss at iteratioin 1.0769695540513622
# Loss at iteratioin 1.3426039942233567
# Loss at iteratioin 1.1689840114159074
# Loss at iteratioin 1.1561005592088738
# Loss at iteratioin 1.0497718881499143
# Loss at iteratioin 0.9203142973829115
# Loss at iteratioin 1.1943008676004983
# Loss at iteratioin 1.0812704410255496
# Loss at iteratioin 1.1073101150535
# Loss at iteratioin 1.1561478101304516
# Loss at iteratioin 0.9634699675924103
# Loss at iteratioin 1.0721943399956246
# Loss at iteratioin 1.3445677061457502
# Loss at iteratioin 1.163868051650523
# Loss at iteratioin 1.1511626444818677
# Loss at iteratioin 1.0461312303783274
# Loss at iteratioin 0.9154314007111427
# Loss at iteratioin 1.1922520902203506
# Loss at iteratioin 1.0775107721556647
# Loss at iteratioin 1.10276409794663
# Loss at iteratioin 1.1548477501786478
# Loss at iteratioin 0.9577544250663191
# Loss at iteratioin 1.06818806648741
# Loss at iteratioin 1.3464360824698933
# Loss at iteratioin 1.1597697308699786
# Loss at iteratioin 1.1471861913033894
# Loss at iteratioin 1.0429924950176332
# Loss at iteratioin 0.9113232551908097
# Loss at iteratioin 1.1905035838417322
# Loss at iteratioin 1.074282021799553
# Loss at iteratioin 1.0988713455384633
# Loss at iteratioin 1.1541098102978518
# Loss at iteratioin 0.9529106315681937
# Loss at iteratioin 1.0647358964898204
# Loss at iteratioin 1.3481504773293818
# Loss at iteratioin 1.1564382450460857
# Loss at iteratioin 1.1439177235446172
# Loss at iteratioin 1.0401997636188043
# Loss at iteratioin 0.9077910366996441
# Loss at iteratioin 1.1889607367589894
# Loss at iteratioin 1.0714383279529636
# Loss at iteratioin 1.0954527438346495
# Loss at iteratioin 1.1537629967901333
# Loss at iteratioin 0.948726532389556
# Loss at iteratioin 1.0616951365056486
# Loss at iteratioin 1.3496844225155469
# Loss at iteratioin 1.153696140047594
# Loss at iteratioin 1.14118201537331
# Loss at iteratioin 1.0376517394228222
# Loss at iteratioin 0.9046975850345982
# Loss at iteratioin 1.1875606723299281
# Loss at iteratioin 1.0688811703148657
# Loss at iteratioin 1.0923870069154917
# Loss at iteratioin 1.153691093309152
# Loss at iteratioin 0.9450528571124084
# Loss at iteratioin 1.0589677875354377
# Loss at iteratioin 1.3510291889810246
# Loss at iteratioin 1.1514143246527622
# Loss at iteratioin 1.1388546287252748
# Loss at iteratioin 1.0352808647691518
# Loss at iteratioin 0.9019455048473698
# Loss at iteratioin 1.1862605285288417
# Loss at iteratioin 1.0665422771981106
# Loss at iteratioin 1.0895898842399474
# Loss at iteratioin 1.153813291512158
# Loss at iteratioin 0.9417816728627121
# Loss at iteratioin 1.056484640670762
# Loss at iteratioin 1.3521859365140305
# Loss at iteratioin 1.149496746505356
# Loss at iteratioin 1.1368452082969007
# Loss at iteratioin 1.0330411538065316
# Loss at iteratioin 0.899463964245725
# Loss at iteratioin 1.185030543393671
# Loss at iteratioin 1.0643733095301033
# Loss at iteratioin 1.087001567711541
# Loss at iteratioin 1.1540723928135126
# Loss at iteratioin 0.9388331883576527
# Loss at iteratioin 1.0541956450527787
# Loss at iteratioin 1.3531612941956237
# Loss at iteratioin 1.147870590407148
# Loss at iteratioin 1.1350869100134724
# Loss at iteratioin 1.030900801514732
# Loss at iteratioin 0.8972003977816666
# Loss at iteratioin 1.1838497872510148
# Loss at iteratioin 1.0623393979033262
# Loss at iteratioin 1.0845787965488523
# Loss at iteratioin 1.1544273511895062
# Loss at iteratioin 0.9361473039802546
# Loss at iteratioin 1.0520638547515189
# Loss at iteratioin 1.3539648081097397
# Loss at iteratioin 1.1464797871747936
# Loss at iteratioin 1.133529487744506
# Loss at iteratioin 1.0288375381550057
# Loss at iteratioin 0.8951151100510981
# Loss at iteratioin 1.1827034281491577
# Loss at iteratioin 1.0604149689053586
# Loss at iteratioin 1.0822897604633566
# Loss at iteratioin 1.1548484091201798
# Loss at iteratioin 0.9336780175735445
# Loss at iteratioin 1.050061503212841
# Loss at iteratioin 1.3546074413299802
# Loss at iteratioin 1.1452805871774188
# Loss at iteratioin 1.1321346456617953
# Loss at iteratioin 1.026835625156457
# Loss at iteratioin 0.8931776634497093
# Loss at iteratioin 1.1815809241678137
# Loss at iteratioin 1.058580981349081
# Loss at iteratioin 1.0801107253436915
# Loss at iteratioin 1.1553138383911954
# Loss at iteratioin 0.9313896160378865
# Loss at iteratioin 1.0481673874679007
# Loss at iteratioin 1.355100683713013
# Loss at iteratioin 1.1442384652444413
# Loss at iteratioin 1.1308728391606402
# Loss at iteratioin 1.0248838653622727
# Loss at iteratioin 0.89136440009863
# Loss at iteratioin 1.1804747968003164
# Loss at iteratioin 1.0568230569877
# Loss at iteratioin 1.0780237495897393
# Loss at iteratioin 1.1558077052724727
# Loss at iteratioin 0.9292540209723006
# Loss at iteratioin 1.0463650833804694
# Loss at iteratioin 1.355456023186731
# Loss at iteratioin 1.1433259090514327
# Loss at iteratioin 1.1297210275141
# Loss at iteratioin 1.0229742580287962
# Loss at iteratioin 0.8896567053402626
# Loss at iteratioin 1.179379780151031
# Loss at iteratioin 1.0551301930401256
# Loss at iteratioin 1.076015108232952
# Loss at iteratioin 1.1563183074848915
# Loss at iteratioin 0.9272489012730133
# Loss at iteratioin 1.0446417022956604
# Loss at iteratioin 1.355684635292903
# Loss at iteratioin 1.1425208085930663
# Loss at iteratioin 1.1286610667534274
# Loss at iteratioin 1.0211010737246102
# Loss at iteratioin 0.8880397680993108
# Loss at iteratioin 1.1782922198143226
# Loss at iteratioin 1.053493861270846
# Loss at iteratioin 1.0740741864732328
# Loss at iteratioin 1.156837062320021
# Loss at iteratioin 0.9253563077796942
# Loss at iteratioin 1.0429870087171753
# Loss at iteratioin 1.3557972064003287
# Loss at iteratioin 1.1418052637039542
# Loss at iteratioin 1.1276785422033435
# Loss at iteratioin 1.0192602085363869
# Loss at iteratioin 0.8865016813669525
# Loss at iteratioin 1.1772096415379123
# Loss at iteratioin 1.0519073686513518
# Loss at iteratioin 1.0721926906348114
# Loss at iteratioin 1.157357704134815
# Loss at iteratioin 0.9235616706497182
# Loss at iteratioin 1.0413927837775057
# Loss at iteratioin 1.3558038396240497
# Loss at iteratioin 1.1411646880537427
# Loss at iteratioin 1.1267619084910747
# Loss at iteratioin 1.0174487275345356
# Loss at iteratioin 0.8850327799698415
# Loss at iteratioin 1.1761304376942034
# Loss at iteratioin 1.0503653979002359
# Loss at iteratioin 1.0703640775357626
# Loss at iteratioin 1.1578756979278304
# Loss at iteratioin 0.9218530532956966
# Loss at iteratioin 1.0398523591842095
# Loss at iteratioin 1.355714012201279
# Loss at iteratioin 1.1405871270919288
# Loss at iteratioin 1.1259018481110878
# Loss at iteratioin 1.0156645385864316
# Loss at iteratioin 0.8836251466969215
# Loss at iteratioin 1.175053636941639
# Loss at iteratioin 1.0488636734926045
# Loss at iteratioin 1.0685831365398077
# Loss at iteratioin 1.1583878062896282
# Loss at iteratioin 0.9202205906475381
# Loss at iteratioin 1.0383602713995663
# Loss at iteratioin 1.3555365648718212
# Loss at iteratioin 1.1400627328190227
# Loss at iteratioin 1.125090787625359
# Loss at iteratioin 1.0139061572383699
# Loss at iteratioin 0.882272239695516
# Loss at iteratioin 1.1739787335336636
# Loss at iteratioin 1.047398716312176
# Loss at iteratioin 1.0668456798898993
# Loss at iteratioin 1.1588917667693182
# Loss at iteratioin 0.9186560616783712
# Loss at iteratioin 1.036912001913541
# Loss at iteratioin 1.3552797109985264
# Loss at iteratioin 1.139583355138825
# Loss at iteratioin 1.1243225290688388
# Loss at iteratioin 1.0121725360306817
# Loss at iteratioin 0.8809686084103281
# Loss at iteratioin 1.1729055599656881
# Loss at iteratioin 1.0459676616578806
# Loss at iteratioin 1.0651483108561386
# Loss at iteratioin 1.1593860497235289
# Loss at iteratioin 0.9171525609399205
# Loss at iteratioin 1.03550378002018
# Loss at iteratioin 1.3549510576144768
# Loss at iteratioin 1.1391422209794313
# Loss at iteratioin 1.1235919665643288
# Loss at iteratioin 1.0104629399078113
# Loss at iteratioin 0.8797096749652854
# Loss at iteratioin 1.1718341914735195
# Loss at iteratioin 1.0445681230135009
# Loss at iteratioin 1.0634882484875834
# Loss at iteratioin 1.1598696754696225
# Loss at iteratioin 0.9157042439226899
# Loss at iteratioin 1.034132431546717
# Loss at iteratioin 1.3545576333806915
# Loss at iteratioin 1.1387336802520382
# Loss at iteratioin 1.122894866651785
# Loss at iteratioin 1.008776854924279
# Loss at iteratioin 0.8784915644524263
# Loss at iteratioin 1.1707648741740442
# Loss at iteratioin 1.0431980891985484
# Loss at iteratioin 1.0618631940041854
# Loss at iteratioin 1.1603420755542282
# Loss at iteratioin 0.914306128018279
# Loss at iteratioin 1.0327952617598424
# Loss at iteratioin 1.354105920219085
# Loss at iteratioin 1.1383530032378308
# Loss at iteratioin 1.1222276967361065
# Loss at iteratioin 1.0071139212032127
# Loss at iteratioin 0.877310972139064
# Loss at iteratioin 1.1696979709041335
# Loss at iteratioin 1.0418558460913234
# Loss at iteratioin 1.060271228141023
# Loss at iteratioin 1.160802987110319
# Loss at iteratioin 0.9129539357457055
# Loss at iteratioin 1.0314899639625588
# Loss at iteratioin 1.353601886532602
# Loss at iteratioin 1.1379962179186456
# Loss at iteratioin 1.1215874902074676
# Loss at iteratioin 1.005473883686883
# Loss at iteratioin 0.8761650587996793
# Loss at iteratioin 1.168633920403645
# Loss at iteratioin 1.0405399165946814
# Loss at iteratioin 1.0587107317228317
# Loss at iteratioin 1.1612523722102452
# Loss at iteratioin 0.9116439703761164
# Loss at iteratioin 1.0302145475923365
# Loss at iteratioin 1.3530510206709696
# Loss at iteratioin 1.1376599785962562
# Loss at iteratioin 1.1209717397448657
# Loss at iteratioin 1.00385655601788
# Loss at iteratioin 0.8750513676539361
# Loss at iteratioin 1.1675732066199767
# Loss at iteratioin 1.0392490142546622
# Loss at iteratioin 1.0571803238293622
# Loss at iteratioin 1.1616903562176732
# Loss at iteratioin 0.9103730165885844
# Loss at iteratioin 1.0289672812567683
# Loss at iteratioin 1.3524583637904133
# Loss at iteratioin 1.1373414592100362
# Loss at iteratioin 1.1203783124447102
# Loss at iteratioin 1.0022617941577419
# Loss at iteratioin 0.8739677580315264
# Loss at iteratioin 1.1665163357272297
# Loss at iteratioin 1.037982007174982
# Loss at iteratioin 1.055678813391246
# Loss at iteratioin 1.162117180655683
# Loss at iteratioin 0.9091382606067608
# Loss at iteratioin 1.0277466473069694
# Loss at iteratioin 1.3518285415793208
# Loss at iteratioin 1.1370382662875853
# Loss at iteratioin 1.119805381969166
# Loss at iteratioin 1.0006894772534163
# Loss at iteratioin 0.8729123520789585
# Loss at iteratioin 1.165463819047628
# Loss at iteratioin 1.036737889752144
# Loss at iteratioin 1.054205161118007
# Loss at iteratioin 1.1625331672143377
# Loss at iteratioin 0.9079372256009296
# Loss at iteratioin 1.026551305391908
# Loss at iteratioin 1.3511657945366458
# Loss at iteratioin 1.1367483676011507
# Loss at iteratioin 1.1192513740520416
# Loss at iteratioin 0.9991394939120581
# Loss at iteratioin 0.8718834917025505
# Loss at iteratioin 1.1644161605008092
# Loss at iteratioin 1.0355157603921339
# Loss at iteratioin 1.0527584494300506
# Loss at iteratioin 1.1629386903367174
# Loss at iteratioin 0.9067677191295203
# Loss at iteratioin 1.025380063053671
# Loss at iteratioin 1.3504740066326675
# Loss at iteratioin 1.1364700334609372
# Loss at iteratioin 1.1187149225494
# Loss at iteratioin 0.9976117325166651
# Loss at iteratioin 0.8708797035950612
# Loss at iteratioin 1.1633738475322115
# Loss at iteratioin 1.034314803832376
# Loss at iteratioin 1.0513378586304793
# Loss at iteratioin 1.163334156429259
# Loss at iteratioin 0.9056277901339321
# Loss at iteratioin 1.0242318518794546
# Loss at iteratioin 1.3497567322765613
# Loss at iteratioin 1.1362017882296092
# Loss at iteratioin 1.1181948338588348
# Loss at iteratioin 0.9961060745605259
# Loss at iteratioin 0.8698996706828948
# Loss at iteratioin 1.1623373447159306
# Loss at iteratioin 1.033134277031783
# Loss at iteratioin 1.049942647969343
# Loss at iteratioin 1.1637199881973448
# Loss at iteratioin 0.904515693557935
# Loss at iteratioin 1.0231057080659507
# Loss at iteratioin 1.3490172215778602
# Loss at iteratioin 1.1359423701437297
# Loss at iteratioin 1.1176900580127502
# Loss at iteratioin 0.9946223902332236
# Loss at iteratioin 0.8689422087006198
# Loss at iteratioin 1.1613070894118487
# Loss at iteratioin 1.0319734978421222
# Loss at iteratioin 1.048572140563631
# Loss at iteratioin 1.1640966129507841
# Loss at iteratioin 0.9034298610860408
# Loss at iteratioin 1.0220007565074474
# Loss at iteratioin 1.3482584439297098
# Loss at iteratioin 1.1356906979159527
# Loss at iteratioin 1.117199665117671
# Loss at iteratioin 0.9931605356800632
# Loss at iteratioin 0.8680062468809836
# Loss at iteratioin 1.1602834889971516
# Loss at iteratioin 1.0308318358600526
# Loss at iteratioin 1.0472257113698136
# Loss at iteratioin 1.1644644539851714
# Loss at iteratioin 0.9023688768185935
# Loss at iteratioin 1.0209161977128203
# Loss at iteratioin 1.3474831099678697
# Loss at iteratioin 1.1354458428943204
# Loss at iteratioin 1.1167228260930786
# Loss at iteratioin 0.9917203514980697
# Loss at iteratioin 0.8670908119642908
# Loss at iteratioin 1.15926691929971
# Loss at iteratioin 1.029708704998488
# Loss at iteratioin 1.0459027775826528
# Loss at iteratioin 1.1648239243449119
# Loss at iteratioin 0.9013314569500488
# Loss at iteratioin 1.0198512970047229
# Loss at iteratioin 1.3466936919753807
# Loss at iteratioin 1.135207005792537
# Loss at iteratioin 1.1162587968807025
# Loss at iteratioin 0.990301662137786
# Loss at iteratioin 0.866195014897373
# Loss at iteratioin 1.1582577239434597
# Loss at iteratioin 1.0286035574208328
# Loss at iteratioin 1.044602790969016
# Loss at iteratioin 1.1651754224273458
# Loss at iteratioin 0.9003164327093904
# Loss at iteratioin 1.0188053755682644
# Loss at iteratioin 1.3458924428119132
# Loss at iteratioin 1.134973497192726
# Loss at iteratioin 1.1158069054643205
# Loss at iteratioin 0.9889042759601719
# Loss at iteratioin 0.8653180397214643
# Loss at iteratioin 1.1572562143798177
# Loss at iteratioin 1.0275158785611243
# Loss at iteratioin 1.0433252317492332
# Loss at iteratioin 1.1655193290060508
# Loss at iteratioin 0.8993227359714215
# Loss at iteratioin 1.0177778030048348
# Loss at iteratioin 1.3450814134512599
# Loss at iteratioin 1.134744721171321
# Loss at iteratioin 1.115366541172395
# Loss at iteratioin 0.9875279857585717
# Loss at iteratioin 0.8644591342490296
# Loss at iteratioin 1.1562626704288252
# Loss at iteratioin 1.0264451830137051
# Loss at iteratioin 1.0420696037188864
# Loss at iteratioin 1.1658560053434728
# Loss at iteratioin 0.8983493870648913
# Loss at iteratioin 1.0167679911155958
# Loss at iteratioin 1.3442624692116834
# Loss at iteratioin 1.1345201615178884
# Loss at iteratioin 1.1149371458399542
# Loss at iteratioin 0.9861725696018735
# Loss at iteratioin 0.8636176022086108
# Loss at iteratioin 1.1552773411924258
# Loss at iteratioin 1.02539101112247
# Loss at iteratioin 1.0408354303664877
# Loss at iteratioin 1.1661857921346894
# Loss at iteratioin 0.8973954843956273
# Loss at iteratioin 1.0157753886932281
# Loss at iteratioin 1.3434373047629915
# Loss at iteratioin 1.1342993701124082
# Loss at iteratioin 1.1145182064884203
# Loss at iteratioin 0.9848377918901887
# Loss at iteratioin 0.8627927965990645
# Loss at iteratioin 1.154300446232574
# Loss at iteratioin 1.0243529261355426
# Loss at iteratioin 1.0396222517915652
# Loss at iteratioin 1.1665090090801276
# Loss at iteratioin 0.8964601955757139
# Loss at iteratioin 1.014799477143171
# Loss at iteratioin 1.3426074579919707
# Loss at iteratioin 1.1340819571037521
# Loss at iteratioin 1.1141092492474476
# Loss at iteratioin 0.9835234045413147
# Loss at iteratioin 0.8619841140439166
# Loss at iteratioin 1.1533321769306557
# Loss at iteratioin 1.0233305118189695
# Loss at iteratioin 1.0384296222663059
# Loss at iteratioin 1.1668259549289335
# Loss at iteratioin 0.8955427498076544
# Loss at iteratioin 1.0138397667894246
# Loss at iteratioin 1.3417743228046604
# Loss at iteratioin 1.1338675825946825
# Loss at iteratioin 1.1137098342950593
# Loss at iteratioin 0.9822291482468671
# Loss at iteratioin 0.8611909899758252
# Loss at iteratioin 1.1523726979633775
# Loss at iteratioin 1.0223233704446204
# Loss at iteratioin 1.037257108314559
# Loss at iteratioin 1.1671369078691431
# Loss at iteratioin 0.8946424313186219
# Loss at iteratioin 1.0128957937469707
# Loss at iteratioin 1.3409391609403067
# Loss at iteratioin 1.1336559495896208
# Loss at iteratioin 1.1133195516341543
# Loss at iteratioin 0.9809547537528048
# Loss at iteratioin 0.8604128945125334
# Loss at iteratioin 1.1514221488450391
# Loss at iteratioin 1.0213311210844127
# Loss at iteratioin 1.0361042872063575
# Loss at iteratioin 1.1674421261679517
# Loss at iteratioin 0.8937585736769234
# Loss at iteratioin 1.0119671172644735
# Loss at iteratioin 1.3401031128678522
# Loss at iteratioin 1.133446798003011
# Loss at iteratioin 1.1129380175571142
# Loss at iteratioin 0.979699943131199
# Loss at iteratioin 0.85964932891086
# Loss at iteratioin 1.1504806454977121
# Loss at iteratioin 1.020353398156268
# Loss at iteratioin 1.0349707457856305
# Loss at iteratioin 1.1677418489867462
# Loss at iteratioin 0.8928905548525556
# Loss at iteratioin 1.0110533174583252
# Loss at iteratioin 1.339267207831739
# Loss at iteratioin 1.1332398995601725
# Loss at iteratioin 1.112564871677393
# Loss at iteratioin 0.9784644310194262
# Loss at iteratioin 0.8588998225055682
# Loss at iteratioin 1.149548281820044
# Loss at iteratioin 1.0193898501777456
# Loss at iteratioin 1.0338560795644374
# Loss at iteratioin 1.16803629731246
# Loss at iteratioin 0.8920377929078118
# Loss at iteratioin 1.0101539933731458
# Loss at iteratioin 1.3384323731097223
# Loss at iteratioin 1.1330350534505578
# Loss at iteratioin 1.1121997744289602
# Loss at iteratioin 0.9772479258100825
# Loss at iteratioin 0.858163930056341
# Loss at iteratioin 1.1486251312326539
# Loss at iteratioin 1.0184401386916335
# Loss at iteratioin 1.032759892029662
# Loss at iteratioin 1.1683256749601318
# Loss at iteratioin 0.8911997422233817
# Loss at iteratioin 1.0092687613152567
# Loss at iteratioin 1.3375994425413529
# Loss at iteratioin 1.1328320826164022
# train loss 0.8463131396685666
# valid loss 0.21146831522268722
# Loss at iteratioin 1.0763384729108654
# Loss at iteratioin 0.9754478706484665
# Loss at iteratioin 1.2074233546950763
# Loss at iteratioin 1.162799412209441
# Loss at iteratioin 1.0269333414128892
# Loss at iteratioin 1.0464919511487467
# Loss at iteratioin 1.177149332695118
# Loss at iteratioin 0.8684152311458923
# Loss at iteratioin 1.0105477851298101
# Loss at iteratioin 1.323000758314866
# Loss at iteratioin 1.1385691496753056
# Loss at iteratioin 1.0739142887473383
# Loss at iteratioin 0.9723842599888135
# Loss at iteratioin 1.2045472933725938
# Loss at iteratioin 1.1620819703137757
# Loss at iteratioin 1.0261001775735326
# Loss at iteratioin 1.0438673824951057
# Loss at iteratioin 1.1793171742580064
# Loss at iteratioin 0.8669857643588104
# Loss at iteratioin 1.0109767500175622
# Loss at iteratioin 1.3231280978473476
# Loss at iteratioin 1.1379296671903314
# Loss at iteratioin 1.0725795648990617
# Loss at iteratioin 0.9703325156169802
# Loss at iteratioin 1.202879440978497
# Loss at iteratioin 1.1612305526708675
# Loss at iteratioin 1.0255950452979061
# Loss at iteratioin 1.0419930399840902
# Loss at iteratioin 1.1803041229949542
# Loss at iteratioin 0.865770778627859
# Loss at iteratioin 1.0109917644332354
# Loss at iteratioin 1.3230067352291284
# Loss at iteratioin 1.1374491361093062
# Loss at iteratioin 1.0717140637358555
# Loss at iteratioin 0.9687236623157202
# Loss at iteratioin 1.2017462340390879
# Loss at iteratioin 1.1603942329448225
# Loss at iteratioin 1.025122868229897
# Loss at iteratioin 1.04047086633486
# Loss at iteratioin 1.180790291052042
# Loss at iteratioin 0.8646585064705656
# Loss at iteratioin 1.0108008551090293
# Loss at iteratioin 1.3227174285203716
# Loss at iteratioin 1.1370492776568053
# Loss at iteratioin 1.0710184739278206
# Loss at iteratioin 0.9673524887814744
# Loss at iteratioin 1.2008991919076009
# Loss at iteratioin 1.1595828280145384
# Loss at iteratioin 1.024609932997299
# Loss at iteratioin 1.0391318864745434
# Loss at iteratioin 1.1810604818591972
# Loss at iteratioin 0.8636180355586378
# Loss at iteratioin 1.0104974641841526
# Loss at iteratioin 1.3223151766434194
# Loss at iteratioin 1.1366893747815199
# Loss at iteratioin 1.0703962077518345
# Loss at iteratioin 0.9661267690165014
# Loss at iteratioin 1.2002260518403027
# Loss at iteratioin 1.1587898599302222
# Loss at iteratioin 1.0240473789606093
# Loss at iteratioin 1.0378958523523116
# Loss at iteratioin 1.181240162074707
# Loss at iteratioin 0.8626372873127106
# Loss at iteratioin 1.0101255499790436
# Loss at iteratioin 1.3218348800538684
# Loss at iteratioin 1.1363482777231029
# Loss at iteratioin 1.0698148173846753
# Loss at iteratioin 0.9650000167986473
# Loss at iteratioin 1.1996673426066558
# Loss at iteratioin 1.1580078722824865
# Loss at iteratioin 1.0234428910468572
# Loss at iteratioin 1.0367220529388017
# Loss at iteratioin 1.1813863511480622
# Loss at iteratioin 0.8617085984423355
# Loss at iteratioin 1.0097075120198733
# Loss at iteratioin 1.3212991448722222
# Loss at iteratioin 1.1360155289904394
# Loss at iteratioin 1.069262189016175
# Loss at iteratioin 0.9639463277242918
# Loss at iteratioin 1.199187745716072
# Loss at iteratioin 1.1572315898375993
# Loss at iteratioin 1.0228063721917975
# Loss at iteratioin 1.0355888342163246
# Loss at iteratioin 1.1815251490497343
# Loss at iteratioin 0.8608254782423321
# Loss at iteratioin 1.0092559352655608
# Loss at iteratioin 1.3207231717171501
# Loss at iteratioin 1.1356863459426512
# Loss at iteratioin 1.0687327847916157
# Loss at iteratioin 0.9629499573400404
# Loss at iteratioin 1.1987647458216921
# Loss at iteratioin 1.1564579053732962
# Loss at iteratioin 1.0221462799313659
# Loss at iteratioin 1.0344842938773755
# Loss at iteratioin 1.1816681168524323
# Loss at iteratioin 0.8599820767512958
# Loss at iteratioin 1.0087786577741813
# Loss at iteratioin 1.3201175933909848
# Loss at iteratioin 1.1353588545589728
# Loss at iteratioin 1.0682233324856132
# Loss at iteratioin 0.962000614960645
# Loss at iteratioin 1.1983833863083286
# Loss at iteratioin 1.1556852498045767
# Loss at iteratioin 1.021469133999085
# Loss at iteratioin 1.0334017456258155
# Loss at iteratioin 1.1818198164667613
# Loss at iteratioin 0.8591731981319087
# Loss at iteratioin 1.008281049402381
# Loss at iteratioin 1.3194901229134264
# Loss at iteratioin 1.135032600448516
# Loss at iteratioin 1.0677314798621504
# Loss at iteratioin 0.9610911545851645
# Loss at iteratioin 1.1980334877735306
# Loss at iteratioin 1.15491302159735
# Loss at iteratioin 1.0207798252664626
# Loss at iteratioin 1.032337379876593
# Loss at iteratioin 1.181981435427978
# Loss at iteratioin 0.8583943425225908
# Loss at iteratioin 1.0077670869209208
# Loss at iteratioin 1.3188465328219823
# Loss at iteratioin 1.134707765514091
# Loss at iteratioin 1.0672553642118738
# Loss at iteratioin 0.9602163543424862
# Loss at iteratioin 1.1977080128050888
# Loss at iteratioin 1.1541411886511617
# Loss at iteratioin 1.0200820256002894
# Loss at iteratioin 1.0312890046148324
# Loss at iteratioin 1.1821525822949848
# Loss at iteratioin 0.8576416902730972
# Loss at iteratioin 1.0072398882560427
# Loss at iteratioin 1.3181912556318012
# Loss at iteratioin 1.1343847677251953
# Loss at iteratioin 1.0667934566676476
# Loss at iteratioin 0.9593722300090786
# Loss at iteratioin 1.1974020382583077
# Loss at iteratioin 1.1533700352586684
# Loss at iteratioin 1.019378525305135
# Loss at iteratioin 1.030255346686407
# Loss at iteratioin 1.1823321885528608
# Loss at iteratioin 0.856912041159134
# Loss at iteratioin 1.0067019934026764
# Loss at iteratioin 1.3175277650394863
# Loss at iteratioin 1.1340640657800167
# Loss at iteratioin 1.0663444871789374
# Loss at iteratioin 0.9585556291758769
# Loss at iteratioin 1.1971120828698938
# Loss at iteratioin 1.1526000079225234
# Loss at iteratioin 1.0186714789771105
# Loss at iteratioin 1.0292356559538494
# Loss at iteratioin 1.1825189599356072
# Loss at iteratioin 0.8562027329261925
# Loss at iteratioin 1.0061555219774885
# Loss at iteratioin 1.3168588267328771
# Loss at iteratioin 1.1337460713914151
# Loss at iteratioin 1.0659073944545632
# Loss at iteratioin 0.9577639814118459
# Loss at iteratioin 1.1968356567711325
# Loss at iteratioin 1.1518316235008554
# Loss at iteratioin 1.0179625776660772
# Loss at iteratioin 1.0282294780297359
# Loss at iteratioin 1.1827115961242134
# Loss at iteratioin 0.8555115565609112
# Loss at iteratioin 1.0056022684313324
# Loss at iteratioin 1.3161866692870252
# Loss at iteratioin 1.1334311166435742
# Loss at iteratioin 1.0654812862365168
# Loss at iteratioin 0.9569951390347824
# Loss at iteratioin 1.1965709552900017
# Loss at iteratioin 1.1510654154018458
# Loss at iteratioin 1.017253168530342
# Loss at iteratioin 1.0272365228241829
# Loss at iteratioin 1.1829088906064715
# Loss at iteratioin 0.8548366777366282
# Loss at iteratioin 1.0050437644918746
# Loss at iteratioin 1.3155131045155197
# Loss at iteratioin 1.133119448347533
# Loss at iteratioin 1.0650654064158314
# Loss at iteratioin 0.956247272355169
# Loss at iteratioin 1.1963166489271562
# Loss at iteratioin 1.1503019027319308
# Loss at iteratioin 1.016544338622149
# Loss at iteratioin 1.0262565883573098
# Loss at iteratioin 1.1831097689881893
# Loss at iteratioin 0.8541765684121118
# Loss at iteratioin 1.0044813235321537
# Loss at iteratioin 1.3148396148143415
# Loss at iteratioin 1.1328112346373902
# Loss at iteratioin 1.0646591080095387
# Loss at iteratioin 0.9555187986060927
# Loss at iteratioin 1.1960717384493735
# Loss at iteratioin 1.1495415732642456
# Loss at iteratioin 1.015836974433795
# Loss at iteratioin 1.0252895167767435
# Loss at iteratioin 1.1833132964851407
# Loss at iteratioin 0.853529949437402
# Loss at iteratioin 1.0039160743265618
# Loss at iteratioin 1.3141674182610932
# Loss at iteratioin 1.1325065762346527
# Loss at iteratioin 1.064261831334969
# Loss at iteratioin 0.9548083322257317
# Loss at iteratioin 1.195835454539822
# Loss at iteratioin 1.1487848747452265
# Loss at iteratioin 1.0151318049949434
# Loss at iteratioin 1.0243351692691922
# Loss at iteratioin 1.1835186708177934
# Loss at iteratioin 0.8528957434691319
# Loss at iteratioin 1.0033489880708795
# Loss at iteratioin 1.313497518264225
# Loss at iteratioin 1.1322055186473365
# Loss at iteratioin 1.0638730866499702
# Loss at iteratioin 0.9541146489929051
# Loss at iteratioin 1.1956071881643997
# Loss at iteratioin 1.148032211239996
# Loss at iteratioin 1.0144294336739215
# Loss at iteratioin 1.0233934120951191
# Loss at iteratioin 1.183725208995089
# Loss at iteratioin 0.8522730368657765
# Loss at iteratioin 1.0027809007465236
# Loss at iteratioin 1.312830742176036
# Loss at iteratioin 1.1319080635914105
# Loss at iteratioin 1.0634924404940247
# Loss at iteratioin 0.9534366593606539
# Loss at iteratioin 1.1953864422271179
# Loss at iteratioin 1.1472839425131864
# Loss at iteratioin 1.013730362097374
# Loss at iteratioin 1.0224641091697118
# Loss at iteratioin 1.183932332325881
# Loss at iteratioin 0.8516610490891149
# Loss at iteratioin 1.002212532002857
# Loss at iteratioin 1.3121677718188147
# Loss at iteratioin 1.1316141789620004
# Loss at iteratioin 1.063119505010599
# Loss at iteratioin 0.9527733880445706
# Loss at iteratioin 1.1951727980370899
# Loss at iteratioin 1.146540385214211
# Loss at iteratioin 1.0130350084724684
# Loss at iteratioin 1.0215471184762601
# Loss at iteratioin 1.1841395517762152
# Loss at iteratioin 0.8510591082266096
# Loss at iteratioin 1.001644501270915
# Loss at iteratioin 1.3115091679495818
# Loss at iteratioin 1.131323807197181
# Loss at iteratioin 1.062753929623537
# Loss at iteratioin 0.9521239579719178
# Loss at iteratioin 1.1949658921056754
# Loss at iteratioin 1.1458018151011002
# Loss at iteratioin 1.0123437218609377
# Loss at iteratioin 1.020642290694972
# Loss at iteratioin 1.1843464546132991
# Loss at iteratioin 0.8504666314303205
# Loss at iteratioin 1.00107734158443
# Loss at iteratioin 1.3108553900907944
# Loss at iteratioin 1.1310368721162298
# Loss at iteratioin 1.062395394547731
# Loss at iteratioin 0.9514875773512457
# Loss at iteratioin 1.1947654001563301
# Loss at iteratioin 1.1450684698212585
# Loss at iteratioin 1.0116567934726124
# Loss at iteratioin 1.0197494690815252
# Loss at iteratioin 1.184552692665407
# Loss at iteratioin 0.8498831092698012
# Loss at iteratioin 1.000511511457236
# Loss at iteratioin 1.3102068127573028
# Loss at iteratioin 1.1307532844107402
# Loss at iteratioin 1.0620436057172715
# Loss at iteratioin 0.9508635290353915
# Loss at iteratioin 1.1945710261693383
# Loss at iteratioin 1.144340551944306
# Loss at iteratioin 1.0109744657265447
# Loss at iteratioin 1.0188684900190403
# Loss at iteratioin 1.1847579722213537
# Loss at iteratioin 0.8493080931858382
# Loss at iteratioin 0.9999474050938021
# Loss at iteratioin 1.309563738839555
# Loss at iteratioin 1.1304729459925618
# Loss at iteratioin 1.0616982908040065
# Loss at iteratioin 0.9502511616156222
# Loss at iteratioin 1.1943824949352146
# Loss at iteratioin 1.1436182320541417
# Loss at iteratioin 1.010296939612823
# Loss at iteratioin 1.0179991839013895
# Loss at iteratioin 1.1849620454514527
# Loss at iteratioin 0.8487411853959766
# Loss at iteratioin 0.9993853611638366
# Loss at iteratioin 1.3089264107147238
# Loss at iteratioin 1.130195753394883
# Loss at iteratioin 1.061359196073415
# Loss at iteratioin 0.9496498818567876
# Loss at iteratioin 1.1941995470450424
# Loss at iteratioin 1.1429016517795358
# Loss at iteratioin 1.0096243807411684
# Loss at iteratioin 1.0171413761472283
# Loss at iteratioin 1.1851647031764703
# Loss at iteratioin 0.8481820307387197
# Loss at iteratioin 0.9988256703391514
# Loss at iteratioin 1.3082950195232486
# Loss at iteratioin 1.1299216004013917
# Loss at iteratioin 1.0610260838837
# Loss at iteratioin 0.9490591481967625
# Loss at iteratioin 1.1940219355644337
# Loss at iteratioin 1.142190926689767
# Loss at iteratioin 1.0089569243603664
# Loss at iteratioin 1.0162948882297749
# Loss at iteratioin 1.1853657687995283
# Loss at iteratioin 0.8476303100530056
# Loss at iteratioin 0.9982685817649434
# Loss at iteratioin 1.307669712950663
# Loss at iteratioin 1.129650380053056
# Loss at iteratioin 1.0606987306799909
# Loss at iteratioin 0.9484784651092681
# Loss at iteratioin 1.1938494238617645
# Loss at iteratioin 1.141486149013034
# Loss at iteratioin 1.0082946795606047
# Loss at iteratioin 1.0154595386591725
# Loss at iteratioin 1.18556509322544
# Loss at iteratioin 0.8470857347766466
# Loss at iteratioin 0.9977143086154636
# Loss at iteratioin 1.307050601782298
# Loss at iteratioin 1.1293819861572933
# Loss at iteratioin 1.0603769253709532
# Loss at iteratioin 0.9479073781806224
# Loss at iteratioin 1.1936817842192788
# Loss at iteratioin 1.1407873901561039
# Loss at iteratioin 1.0076377328192936
# Loss at iteratioin 1.0146351438854055
# Loss at iteratioin 1.1857625506103304
# Loss at iteratioin 0.8465480425158565
# Loss at iteratioin 0.9971630328644958
# Loss at iteratioin 1.3064377654438946
# Loss at iteratioin 1.129116314402028
# Loss at iteratioin 1.0600604680020684
# Loss at iteratioin 0.9473454697864849
# Loss at iteratioin 1.1935187969672922
# Loss at iteratioin 1.1400947030174293
# Loss at iteratioin 1.0069861510135671
# Loss at iteratioin 1.013821519108297
# Loss at iteratioin 1.1859580348053531
# Loss at iteratioin 0.8460169933914518
# Loss at iteratioin 0.996614909383658
# Loss at iteratioin 1.305831256699463
# Loss at iteratioin 1.1288532631580142
# Loss at iteratioin 1.059749168660315
# Loss at iteratioin 0.9467923552796209
# Loss at iteratioin 1.193360249960637
# Loss at iteratioin 1.1394081240949827
# Loss at iteratioin 1.0063399839951515
# Loss at iteratioin 1.0130184789918786
# Loss at iteratioin 1.1861514563787503
# Loss at iteratioin 0.8454923670089473
# Loss at iteratioin 0.9960700694660315
# Loss at iteratioin 1.3052311056453336
# Loss at iteratioin 1.1285927340367683
# Loss at iteratioin 1.059442846560445
# Loss at iteratioin 0.9462476796175991
# Loss at iteratioin 1.1932059382723672
# Loss at iteratioin 1.1387276753958515
# Loss at iteratioin 1.005699266802823
# Loss at iteratioin 1.012225838286468
# Loss at iteratioin 1.1863427401190454
# Loss at iteratioin 0.8449739599321676
# Loss at iteratioin 0.9955286238589172
# Loss at iteratioin 1.3046373231139372
# Loss at iteratioin 1.1283346322582337
# Loss at iteratioin 1.059141329274737
# Loss at iteratioin 0.945711114372452
# Loss at iteratioin 1.1930556640191456
# Loss at iteratioin 1.1380533661581793
# Loss at iteratioin 1.0050640215722328
# Loss at iteratioin 1.0114434123649492
# Loss at iteratioin 1.1865318229383364
# Loss at iteratioin 0.8444615835651893
# Loss at iteratioin 0.9949906653774857
# Loss at iteratioin 1.30404990358067
# Loss at iteratioin 1.128078866871484
# Loss at iteratioin 1.0588444520769416
# Loss at iteratioin 0.9451823550741334
# Loss at iteratioin 1.1929092362605713
# Loss at iteratioin 1.1373851943980342
# Loss at iteratioin 1.0044342591911117
# Loss at iteratioin 1.0106710176811355
# Loss at iteratioin 1.1867186521084296
# Loss at iteratioin 0.843955062367079
# Loss at iteratioin 0.9944562711606052
# Loss at iteratioin 1.303468827651043
# Loss at iteratioin 1.1278253508630112
# Loss at iteratioin 1.05855205737781
# Loss at iteratioin 0.9446611188471554
# Loss at iteratioin 1.1927664709341872
# Loss at iteratioin 1.1367231482947333
# Loss at iteratioin 1.0038099807387983
# Loss at iteratioin 1.0099084721585025
# Loss at iteratioin 1.186903183774137
# Loss at iteratioin 0.8434542323392502
# Loss at iteratioin 0.9939255046210689
# Loss at iteratioin 1.30289406419226
# Loss at iteratioin 1.1275740011800235
# Loss at iteratioin 1.0582639942346737
# Loss at iteratioin 0.9441471423056913
# Loss at iteratioin 1.1926271908015542
# Loss at iteratioin 1.1360672074283487
# Loss at iteratioin 1.003191178741973
# Loss at iteratioin 1.009155595517347
# Loss at iteratioin 1.1870853816976654
# Loss at iteratioin 0.8429589397372574
# Loss at iteratioin 0.9933984171346479
# Loss at iteratioin 1.3023255721627567
# Loss at iteratioin 1.1273247386904832
# Loss at iteratioin 1.057980117921397
# Loss at iteratioin 0.9436401796771763
# Loss at iteratioin 1.1924912253902045
# Loss at iteratioin 1.1354173438828603
# Loss at iteratioin 1.0025778382729198
# Loss at iteratioin 1.008412209547931
# Loss at iteratioin 1.1872652161960167
# Loss at iteratioin 0.8424690399683172
# Loss at iteratioin 0.9928750495057298
# Loss at iteratioin 1.3017633021845432
# Loss at iteratioin 1.1270774880969858
# Loss at iteratioin 1.0577002895479717
# Loss at iteratioin 0.943140001128335
# Loss at iteratioin 1.1923584109227467
# Loss at iteratioin 1.134773523227843
# Loss at iteratioin 1.0019699379122289
# Loss at iteratioin 1.0076781383364966
# Loss at iteratioin 1.1874426632398527
# Loss at iteratioin 0.8419843966432706
# Loss at iteratioin 0.9923554332416124
# Loss at iteratioin 1.3012071978960358
# Loss at iteratioin 1.1268321778179118
# Loss at iteratioin 1.0574243757212816
# Loss at iteratioin 0.9426463912707972
# Loss at iteratioin 1.1922285902287517
# Loss at iteratioin 1.1341357053907917
# Loss at iteratioin 1.0013674505943113
# Loss at iteratioin 1.006953208450323
# Loss at iteratioin 1.1876177036877165
# Loss at iteratioin 0.8415048807576255
# Loss at iteratioin 0.991839591662699
# Loss at iteratioin 1.3006571971171568
# Loss at iteratioin 1.1265887398463061
# Loss at iteratioin 1.0571522482403037
# Loss at iteratioin 0.9421591478262166
# Loss at iteratioin 1.192101612637933
# Loss at iteratioin 1.1335038454313406
# Loss at iteratioin 1.000770344351225
# Loss at iteratioin 1.006237249087311
# Loss at iteratioin 1.1877903226339175
# Loss at iteratioin 0.8410303699809767
# Loss at iteratioin 0.9913275408717342
# Loss at iteratioin 1.3001132328535712
# Loss at iteratioin 1.126347109594584
# Loss at iteratioin 1.0568837838203573
# Loss at iteratioin 0.9416780804331564
# Loss at iteratioin 1.19197733385497
# Loss at iteratioin 1.1328778942277054
# Loss at iteratioin 1.0001785829679843
# Loss at iteratioin 1.0055300921949035
# Loss at iteratioin 1.187960508852076
# Loss at iteratioin 0.8405607480378685
# Loss at iteratioin 0.9908192906017576
# Loss at iteratioin 1.2995752341628208
# Loss at iteratioin 1.1261072257312836
# Loss at iteratioin 1.0566188638420662
# Loss at iteratioin 0.9412030095800529
# Loss at iteratioin 1.1918556158174356
# Loss at iteratioin 1.132257799084769
# Loss at iteratioin 0.9995921265605863
# Loss at iteratioin 1.0048315725625594
# Loss at iteratioin 1.1881282543193088
# Loss at iteratioin 0.84009590416615
# Loss at iteratioin 0.9903148449595148
# Loss at iteratioin 1.2990431269017135
# Loss at iteratioin 1.1258690300145702
# Loss at iteratioin 1.056357374121509
# Loss at iteratioin 0.9407337656503391
# Loss at iteratioin 1.1917363265389234
# Loss at iteratioin 1.1316435042723576
# Loss at iteratioin 0.9990109320864025
# Loss at iteratioin 1.0041415278914527
# Loss at iteratioin 1.1882935538085435
# Loss at iteratioin 0.8396357326412894
# Loss at iteratioin 0.9898142030785809
# Loss at iteratioin 1.2985168343714324
# Loss at iteratioin 1.125632467126033
# Loss at iteratioin 1.0560992046986823
# Loss at iteratioin 0.9402701880673813
# Loss at iteratioin 1.191619339939755
# Loss at iteratioin 1.1310349515013967
# Loss at iteratioin 0.9984349537952405
# Loss at iteratioin 1.0034597988445892
# Loss at iteratioin 1.188456404538492
# Loss at iteratioin 0.8391801323570747
# Loss at iteratioin 0.9893173596943594
# Loss at iteratioin 1.297996277874422
# Loss at iteratioin 1.1253974845073593
# Loss at iteratioin 1.055844249641912
# Loss at iteratioin 0.9398121245282606
# Loss at iteratioin 1.1915045356677127
# Loss at iteratioin 1.1304320803448678
# Loss at iteratioin 0.9978641436282646
# Loss at iteratioin 1.0027862290801133
# Loss at iteratioin 1.1886168058725073
# Loss at iteratioin 0.8387290064547026
# Loss at iteratioin 0.9888243056513369
# Loss at iteratioin 1.2974813771950713
# Loss at iteratioin 1.1251640322017527
# Loss at iteratioin 1.0555924068662488
# Loss at iteratioin 0.9393594303166414
# Loss at iteratioin 1.1913917989111864
# Loss at iteratioin 1.129834828609753
# Loss at iteratioin 0.9972984515710067
# Loss at iteratioin 1.0021206652702084
# Loss at iteratioin 1.1887747590589692
# Loss at iteratioin 0.8382822619935619
# Loss at iteratioin 0.988335028351479
# Loss at iteratioin 1.2969720510144775
# Loss at iteratioin 1.1249320627013706
# Loss at iteratioin 1.0553435779642124
# Loss at iteratioin 0.9389119676860719
# Loss at iteratioin 1.1912810202069448
# Loss at iteratioin 1.1292431326654868
# Loss at iteratioin 0.996737825965903
# Loss at iteratioin 1.0014629571076719
# Loss at iteratioin 1.1889302670070006
# Loss at iteratioin 0.8378398096580749
# Loss at iteratioin 0.9878495121513767
# Loss at iteratioin 1.296468217268135
# Loss at iteratioin 1.124701530801636
# Loss at iteratioin 1.055097668047511
# Loss at iteratioin 0.9384696053059957
# Loss at iteratioin 1.191172095244554
# Loss at iteratioin 1.1286569277338423
# Loss at iteratioin 0.9961822137890892
# Loss at iteratioin 1.0008129573019773
# Loss at iteratioin 1.1890833340922937
# Loss at iteratioin 0.8374015634958264
# Loss at iteratioin 0.9873677387146751
# Loss at iteratioin 1.2959697934541257
# Loss at iteratioin 1.124472393462908
# Loss at iteratioin 1.0548545855985694
# Loss at iteratioin 0.9380322177636338
# Loss at iteratioin 1.191064924669237
# Loss at iteratioin 1.128076148144628
# Loss at iteratioin 0.9956315608956007
# Loss at iteratioin 1.000170521566384
# Loss at iteratioin 1.1892339659886473
# Loss at iteratioin 0.8369674406829458
# Loss at iteratioin 0.986889687325402
# Loss at iteratioin 1.2954766968983586
# Loss at iteratioin 1.12424460967976
# train loss 0.840341492395974
# valid loss 0.20817153125761098
# Loss at iteratioin 1.0546142423308806
# Loss at iteratioin 0.9375996851156352
# Loss at iteratioin 1.19095941388473
# Loss at iteratioin 1.173186176619787
# Loss at iteratioin 0.783869357656567
# Loss at iteratioin 0.9237944069300377
# Loss at iteratioin 1.182279269701906
# Loss at iteratioin 0.8333195257252478
# Loss at iteratioin 0.9844435881343204
# Loss at iteratioin 1.2927861699946308
# Loss at iteratioin 1.125231833120298
# Loss at iteratioin 1.054739916866234
# Loss at iteratioin 0.9380027129234015
# Loss at iteratioin 1.1885737052295602
# Loss at iteratioin 1.1725721948308099
# Loss at iteratioin 0.7850360807699595
# Loss at iteratioin 0.9231249748526388
# Loss at iteratioin 1.1775774287151428
# Loss at iteratioin 0.8323640945025534
# Loss at iteratioin 0.983082637005567
# Loss at iteratioin 1.2905549871921538
# Loss at iteratioin 1.124869187333498
# Loss at iteratioin 1.054955406217047
# Loss at iteratioin 0.9379428279471898
# Loss at iteratioin 1.1866427668033925
# Loss at iteratioin 1.1725831852661395
# Loss at iteratioin 0.7853418164995523
# Loss at iteratioin 0.9227150395578754
# Loss at iteratioin 1.175004881770839
# Loss at iteratioin 0.831761719867701
# Loss at iteratioin 0.982228186288575
# Loss at iteratioin 1.2888766184697036
# Loss at iteratioin 1.1241637547169714
# Loss at iteratioin 1.0548871912401554
# Loss at iteratioin 0.9377056975547775
# Loss at iteratioin 1.1849317053032078
# Loss at iteratioin 1.1728421145992358
# Loss at iteratioin 0.7852496612200555
# Loss at iteratioin 0.9223410324611749
# Loss at iteratioin 1.1735482864529552
# Loss at iteratioin 0.8312231369055065
# Loss at iteratioin 0.9816017481764044
# Loss at iteratioin 1.2875726169037203
# Loss at iteratioin 1.1233611712347669
# Loss at iteratioin 1.054728458892764
# Loss at iteratioin 0.937367956053803
# Loss at iteratioin 1.183406419119506
# Loss at iteratioin 1.1731965760532403
# Loss at iteratioin 0.7849677514509721
# Loss at iteratioin 0.921971286594844
# Loss at iteratioin 1.172702352983162
# Loss at iteratioin 0.8306806919319345
# Loss at iteratioin 0.9810859918292146
# Loss at iteratioin 1.286527654837769
# Loss at iteratioin 1.1225644427770147
# Loss at iteratioin 1.0545557215368375
# Loss at iteratioin 0.9369749681196846
# Loss at iteratioin 1.1820474380622281
# Loss at iteratioin 1.173584364453984
# Loss at iteratioin 0.784592627823685
# Loss at iteratioin 0.9215919564910595
# Loss at iteratioin 1.1722023038754465
# Loss at iteratioin 0.830124906478795
# Loss at iteratioin 0.9806263356730678
# Loss at iteratioin 1.2856653358239016
# Loss at iteratioin 1.1218162169615224
# Loss at iteratioin 1.0543921486052223
# Loss at iteratioin 0.936553338488809
# Loss at iteratioin 1.1808337337753771
# Loss at iteratioin 1.173980490976602
# Loss at iteratioin 0.7841714745042736
# Loss at iteratioin 0.9211986132427432
# Loss at iteratioin 1.1719049695852597
# Loss at iteratioin 0.8295593123069417
# Loss at iteratioin 0.9801956027656706
# Loss at iteratioin 1.284934290207831
# Loss at iteratioin 1.1211312961731006
# Loss at iteratioin 1.0542416689312128
# Loss at iteratioin 0.9361184463189409
# Loss at iteratioin 1.1797450459934162
# Loss at iteratioin 1.1743751060022287
# Loss at iteratioin 0.7837280170101188
# Loss at iteratioin 0.9207914369567451
# Loss at iteratioin 1.1717306129533445
# Loss at iteratioin 0.8289889586012286
# Loss at iteratioin 0.979779790397473
# Loss at iteratioin 1.2842995103139119
# Loss at iteratioin 1.1205115568494994
# Loss at iteratioin 1.0541023891472967
# Loss at iteratioin 0.9356790928634596
# Loss at iteratioin 1.1787635504137004
# Loss at iteratioin 1.1747644868131508
# Loss at iteratioin 0.7832743406461163
# Loss at iteratioin 0.9203724398464896
# Loss at iteratioin 1.1716335338884518
# Loss at iteratioin 0.828417964181295
# Loss at iteratioin 0.9793716080646502
# Loss at iteratioin 1.2837366753938522
# Loss at iteratioin 1.1199531064557682
# Loss at iteratioin 1.0539713038822733
# Loss at iteratioin 0.9352402410021998
# Loss at iteratioin 1.1778741315865107
# Loss at iteratioin 1.1751473849069247
# Loss at iteratioin 0.7828166350665787
# Loss at iteratioin 0.9199441029277566
# Loss at iteratioin 1.1715867733476228
# Loss at iteratioin 0.8278493304612703
# Loss at iteratioin 0.9789672939736118
# Loss at iteratioin 1.2832284885467016
# Loss at iteratioin 1.119449787654599
# Loss at iteratioin 1.053845719735768
# Loss at iteratioin 0.934804618487603
# Loss at iteratioin 1.1770640985832792
# Loss at iteratioin 1.1755235388572296
# Loss at iteratioin 0.782358081563102
# Loss at iteratioin 0.9195087928562385
# Loss at iteratioin 1.1715739397095897
# Loss at iteratioin 0.8272851932826614
# Loss at iteratioin 0.9785649674292711
# Loss at iteratioin 1.2827623464820348
# Loss at iteratioin 1.1189948881560272
# Loss at iteratioin 1.053723545163282
# Loss at iteratioin 0.9343736575060484
# Loss at iteratioin 1.176322791914213
# Loss at iteratioin 1.1758930624972865
# Loss at iteratioin 0.78190032588132
# Loss at iteratioin 0.9190685597583216
# Loss at iteratioin 1.1715847383841715
# Loss at iteratioin 0.8267270737236845
# Loss at iteratioin 0.9781637521305591
# Loss at iteratioin 1.2823288593678326
# Loss at iteratioin 1.1185819457758222
# Loss at iteratioin 1.053603239076149
# Loss at iteratioin 0.9339480459962901
# Loss at iteratioin 1.1756412288115436
# Loss at iteratioin 1.176256191133011
# Loss at iteratioin 0.7814442325594856
# Loss at iteratioin 0.9186251035101777
# Loss at iteratioin 1.171612476137177
# Loss at iteratioin 0.8261760561055259
# Loss at iteratioin 0.9777633030710864
# Loss at iteratioin 1.28192089980822
# Loss at iteratioin 1.1182050926520375
# Loss at iteratioin 1.0534836882368244
# Loss at iteratioin 0.9335280508253418
# Loss at iteratioin 1.1750118133250542
# Loss at iteratioin 1.1766131771089605
# Loss at iteratioin 0.78099027031313
# Loss at iteratioin 0.9181798051507462
# Loss at iteratioin 1.1716526412228825
# Loss at iteratioin 0.8256329051872993
# Loss at iteratioin 0.9773635499721676
# Loss at iteratioin 1.2815329784876854
# Loss at iteratioin 1.1178591665081126
# Loss at iteratioin 1.0533640941379678
# Loss at iteratioin 0.9331137064820401
# Loss at iteratioin 1.1744281031448986
# Loss at iteratioin 1.1769642490948915
# Loss at iteratioin 0.780538707503008
# Loss at iteratioin 0.9177337769133678
# Loss at iteratioin 1.1717020804288887
# Loss at iteratioin 0.8250981440722787
# Loss at iteratioin 0.9769645584292528
# Loss at iteratioin 1.2811608226119449
# Loss at iteratioin 1.117539707810845
# Loss at iteratioin 1.0532438862122293
# Loss at iteratioin 0.9327049244262184
# Loss at iteratioin 1.1738846202243163
# ...
# Loss at iteratioin 0.9113133372994522
# Loss at iteratioin 0.7982750027888725
# Loss at iteratioin 1.0080141668265812
# Loss at iteratioin 1.0395390226651997
# Loss at iteratioin 0.9086738859040084
# Loss at iteratioin 1.180806595904196
# Loss at iteratioin 1.1820279134593528
# Loss at iteratioin 0.7418901386984021
# Loss at iteratioin 1.0451934726108696
# Loss at iteratioin 0.8697271295897528
# Loss at iteratioin 0.9033941151189879
# Loss at iteratioin 0.9110220491050736
# Loss at iteratioin 0.79808957227595
# Loss at iteratioin 1.0076970087323174
# Loss at iteratioin 1.0396144089937331
# Loss at iteratioin 0.9084599932730453
# Loss at iteratioin 1.1809012864392685
# Loss at iteratioin 1.1821234271486951
# Loss at iteratioin 0.7415538909598864
# Loss at iteratioin 1.0450489618157466
# Loss at iteratioin 0.8695418042865126
# Loss at iteratioin 0.9032411288883947
# Loss at iteratioin 0.9107402037888734
# Loss at iteratioin 0.7979051531468221
# Loss at iteratioin 1.0073860746867835
# Loss at iteratioin 1.0396795767393014
# Loss at iteratioin 0.908250117551954
# Loss at iteratioin 1.1809801232514299
# Loss at iteratioin 1.182203180963148
# Loss at iteratioin 0.7412260830350413
# Loss at iteratioin 1.0449127518269952
# Loss at iteratioin 0.8693590641643077
# Loss at iteratioin 0.9030812837626188
# Loss at iteratioin 0.910466774323621
# Loss at iteratioin 0.7977209803884926
# Loss at iteratioin 1.0070810334521259
# Loss at iteratioin 1.039734396259686
# Loss at iteratioin 0.9080435490505258
# Loss at iteratioin 1.1810448028098492
# Loss at iteratioin 1.1822705307684092
# Loss at iteratioin 0.7409056765491341
# Loss at iteratioin 1.044783474150794
# Loss at iteratioin 0.8691786239737519
# Loss at iteratioin 0.9029155281643959
# Loss at iteratioin 0.9102008438450298
# Loss at iteratioin 0.7975366060254934
# Loss at iteratioin 1.0067815834342042
# Loss at iteratioin 1.0397789925670409
# Loss at iteratioin 0.9078396783405464
# Loss at iteratioin 1.1810967563936796
# Loss at iteratioin 1.1823279992344766
# Loss at iteratioin 0.7405918182500495
# Loss at iteratioin 1.0446599178085159
# Loss at iteratioin 0.8690003252597838
# Loss at iteratioin 0.9027446315601652
# Loss at iteratioin 0.9099415977771139
# Loss at iteratioin 0.7973517883525723
# Loss at iteratioin 1.0064874470276237
# Loss at iteratioin 1.039813648728006
# Loss at iteratioin 0.9076379948473046
# Loss at iteratioin 1.181137211021234
# Loss at iteratioin 1.182377488011061
# Loss at iteratioin 0.7402838026023829
# Loss at iteratioin 1.0445410363229288
# Loss at iteratioin 0.8688240707617763
# Loss at iteratioin 0.9025692320039791
# Loss at iteratioin 0.9096883151330364
# Loss at iteratioin 0.797166419112971
# Loss at iteratioin 1.0061983666486263
# Loss at iteratioin 1.0398387424730149
# Loss at iteratioin 0.9074380781030558
# Loss at iteratioin 1.181167231047236
# Loss at iteratioin 1.1824204348029836
# Loss at iteratioin 0.7399810422705534
# Loss at iteratioin 1.0444259392030426
# Loss at iteratioin 0.8686497888809399
# Loss at iteratioin 0.902389868070738
# Loss at iteratioin 0.9094403594220339
# Loss at iteratioin 0.7969804752301148
# Loss at iteratioin 1.0059141018816338
# Loss at iteratioin 1.0398547044437616
# Loss at iteratioin 0.9072395863110958
# Loss at iteratioin 1.1811877478512398
# Loss at iteratioin 1.1824579298534925
# Loss at iteratioin 0.7396830448126862
# Loss at iteratioin 1.0443138765054223
# Loss at iteratioin 0.8684774153119237
# Loss at iteratioin 0.9022070009008856
# Loss at iteratioin 0.909197169636849
# Loss at iteratioin 0.796793986660034
# Loss at iteratioin 1.0056344273735074
# Loss at iteratioin 1.039861990669782
# Loss at iteratioin 0.907042244611393
# Loss at iteratioin 1.1811995819489376
# Loss at iteratioin 1.1824908025079353
# Loss at iteratioin 0.7393893942758869
# Loss at iteratioin 1.0442042211684648
# Loss at iteratioin 0.8683068843265924
# Loss at iteratioin 0.9020210298633242
# Loss at iteratioin 0.9089582516733361
# Loss at iteratioin 0.7966070149527369
# Loss at iteratioin 1.0053591312362435
# Loss at iteratioin 1.0398610644850572
# Loss at iteratioin 0.9068458341762303
# Loss at iteratioin 1.1812034600896637
# Loss at iteratioin 1.1825196856950013
# Loss at iteratioin 0.739099736653114
# Loss at iteratioin 1.0440964515662667
# Loss at iteratioin 0.868138125354804
# Loss at iteratioin 0.9018323040096123
# Loss at iteratioin 0.9087231703953209
# Loss at iteratioin 0.7964196389938059
# Loss at iteratioin 1.0050880137993088
# Loss at iteratioin 1.0398523847572718
# Loss at iteratioin 0.9066501825822081
# Loss at iteratioin 1.1812000288869517
# Loss at iteratioin 1.1825450640806756
# Loss at iteratioin 0.7388137683749132
# Loss at iteratioin 1.0439901354503343
# Loss at iteratioin 0.8679710623564512
# Loss at iteratioin 0.9016411306844399
# Loss at iteratioin 0.9084915424469623
# Loss at iteratioin 0.796231945593886
# Loss at iteratioin 1.0048208866051604
# Loss at iteratioin 1.0398363983660064
# Loss at iteratioin 0.9064551555532974
# Loss at iteratioin 1.18118986594143
# Loss at iteratioin 1.1825673101251157
# Loss at iteratioin 0.7385312271816169
# Loss at iteratioin 1.0438849157397496
# Loss at iteratioin 0.8678056145609438
# Loss at iteratioin 0.9014477821638756
# Loss at iteratioin 0.9082630298378268
# Loss at iteratioin 0.7960440233664724
# Loss at iteratioin 1.0045575715761328
# Loss at iteratioin 1.0398135355540759
# Loss at iteratioin 0.9062606500014128
# Loss at iteratioin 1.1811734890726489
# Loss at iteratioin 1.1825867111563872
# Loss at iteratioin 0.7382518848608675
# Loss at iteratioin 1.0437804982436316
# Loss at iteratioin 0.8676416977809951
# Loss at iteratioin 0.901252500888542
# Loss at iteratioin 0.9080373342772491
# Loss at iteratioin 0.7958559588407307
# Loss at iteratioin 1.0042979003039767
# Loss at iteratioin 1.0397842072259889
# Loss at iteratioin 0.9060665882215597
# Loss at iteratioin 1.1811513640737128
# Loss at iteratioin 1.1826034897573456
# Loss at iteratioin 0.7379755414468656
# Loss at iteratioin 1.0436766412117775
# Loss at iteratioin 0.8674792258729278
# Loss at iteratioin 0.9010555036688995
# Loss at iteratioin 0.9078141922067444
# Loss at iteratioin 0.7956678340922171
# Loss at iteratioin 1.0040417134288884
# Loss at iteratioin 1.039748803564819
# Loss at iteratioin 0.90587291308014
# Loss at iteratioin 1.18112391127996
# Loss at iteratioin 1.182617819162339
# Loss at iteratioin 0.7377020205662572
# Loss at iteratioin 1.043573146526851
# Loss at iteratioin 0.8673181121252403
# Loss at iteratioin 0.9008569851195167
# Loss at iteratioin 0.9075933704656859
# Loss at iteratioin 0.7954797254000849
# Loss at iteratioin 1.003788860085377
# Loss at iteratioin 1.039707693537476
# Loss at iteratioin 0.90567958404106
# Loss at iteratioin 1.1810915111663367
# Loss at iteratioin 1.182629834920021
# Loss at iteratioin 0.7374311656851937
# Loss at iteratioin 1.0434698523261077
# Loss at iteratioin 0.8671582704754638
# Loss at iteratioin 0.9006571205017064
# Loss at iteratioin 0.9073746625210652
# Loss at iteratioin 0.7952917025925293
# Loss at iteratioin 1.0035391973994574
# Loss at iteratioin 1.0396612249925015
# Loss at iteratioin 0.9054865738907153
# Loss at iteratioin 1.1810545091382063
# Loss at iteratioin 1.1826396437545246
# Loss at iteratioin 0.7371628370665468
# Loss at iteratioin 1.0433666268446056
# Loss at iteratioin 0.8669996165204792
# Loss at iteratioin 0.900456068102995
# Loss at iteratioin 0.9071578851933648
# Loss at iteratioin 0.79510382884707
# Loss at iteratioin 1.003292590026514
# Loss at iteratioin 1.0396097251459442
# Loss at iteratioin 0.9052938660423923
# Loss at iteratioin 1.1810132196461731
# Loss at iteratioin 1.1826473303184084
# Loss at iteratioin 0.7368969092886044
# Loss at iteratioin 1.0432633632896033
# Loss at iteratioin 0.8668420683198863
# Loss at iteratioin 0.9002539712477081
# Loss at iteratioin 0.9069428758149081
# Loss at iteratioin 0.7949161607845849
# Loss at iteratioin 1.003048909722479
# Loss at iteratioin 1.0395535013137291
# Loss at iteratioin 0.9051014523196255
# Loss at iteratioin 1.1809679297308853
# Loss at iteratioin 1.1826529623543993
# Loss at iteratioin 0.7366332692094371
# Loss at iteratioin 1.0431599755788168
# Loss at iteratioin 0.8666855470088921
# Loss at iteratioin 0.9000509600094502
# Loss at iteratioin 0.9067294897629432
# Loss at iteratioin 0.7947287487461736
# Loss at iteratioin 1.0028080349432174
# Loss at iteratioin 1.0394928417924596
# Loss at iteratioin 0.9049093311350879
# Loss at iteratioin 1.1809189020851967
# Loss at iteratioin 1.182656594652387
# Loss at iteratioin 0.7363718142865583
# Loss at iteratioin 1.0430563947988685
# Loss at iteratioin 0.8665299772442583
# Loss at iteratioin 0.8998471526797309
# Loss at iteratioin 0.9065175983161622
# Loss at iteratioin 0.7945416371768884
# Loss at iteratioin 1.002569850468513
# Loss at iteratioin 1.0394280168209238
# Loss at iteratioin 0.9047175059961718
# Loss at iteratioin 1.1808663777064945
# Loss at iteratioin 1.1826582720913286
# Loss at iteratioin 0.7361124511811906
# Loss at iteratioin 1.042952566262436
# Loss at iteratioin 0.8663752875085756
# Loss at iteratioin 0.8996426570350476
# Loss at iteratioin 0.906307086789731
# Loss at iteratioin 0.7943548650647722
# Loss at iteratioin 1.0023342470480885
# Loss at iteratioin 1.0393592795758198
# Loss at iteratioin 0.9045259842806279
# Loss at iteratioin 1.1808105782002265
# Loss at iteratioin 1.1826580319837603
# Loss at iteratioin 0.7358550945916793
# Loss at iteratioin 1.042848447062343
# Loss at iteratioin 0.8662214102971189
# Loss at iteratioin 0.8994375714359523
# Loss at iteratioin 0.9060978529099022
# Loss at iteratioin 0.794168466400719
# Loss at iteratioin 1.0021011210677488
# Loss at iteratioin 1.039286867170135
# Loss at iteratioin 0.9043347762356745
# Loss at iteratioin 1.1807517077859988
# Loss at iteratioin 1.1826559058870016
# Loss at iteratioin 0.7355996662724057
# Loss at iteratioin 1.0427440040378835
# Loss at iteratioin 0.8660682822092443
# Loss at iteratioin 0.8992319857850017
# Loss at iteratioin 0.9058898053947018
# Loss at iteratioin 0.7939824706365843
# Loss at iteratioin 1.0018703742342046
# Loss at iteratioin 1.0392110016331129
# Loss at iteratioin 0.9041438941622223
# Loss at iteratioin 1.180689955049577
# Loss at iteratioin 1.1826519210051238
# Loss at iteratioin 0.7353460942036959
# Loss at iteratioin 1.042639212083119
# Loss at iteratioin 0.8659158439635137
# Loss at iteratioin 0.8990259823654232
# Loss at iteratioin 0.9056828627120044
# Loss at iteratioin 0.7937969031272476
# Loss at iteratioin 1.0016419132774037
# Loss at iteratioin 1.0391318908581526
# Loss at iteratioin 0.9039533517525639
# Loss at iteratioin 1.1806254944773922
# Loss at iteratioin 1.182646101275789
# Loss at iteratioin 0.7350943118853585
# Loss at iteratioin 1.0425340527389926
# Loss at iteratioin 0.8657640403529484
# Loss at iteratioin 0.8988196365783581
# Loss at iteratioin 0.9054769519904893
# Loss at iteratioin 0.7936117855480744
# Loss at iteratioin 1.0014156496694064
# Loss at iteratioin 1.0390497295101675
# Loss at iteratioin 0.9037631635553539
# Loss at iteratioin 1.1805584878045008
# Loss at iteratioin 1.1826384682135687
# Loss at iteratioin 0.7348442577320204
# Loss at iteratioin 1.042428513021164
# Loss at iteratioin 0.8656128201541841
# Loss at iteratioin 0.8986130175934383
# Loss at iteratioin 0.9052720080625922
# Loss at iteratioin 0.7934271362831395
# Loss at iteratioin 1.0011914993589426
# Loss at iteratioin 1.0389646998875803
# Loss at iteratioin 0.9035733445461835
# Loss at iteratioin 1.1804890852021979
# Loss at iteratioin 1.1826290415644385
# Loss at iteratioin 0.7345958745527797
# Loss at iteratioin 1.0423225844438022
# Loss at iteratioin 0.8654621360019628
# Loss at iteratioin 0.8984061889249402
# Loss at iteratioin 0.9050679726216596
# Loss at iteratioin 0.7932429707822173
# Loss at iteratioin 1.0009693825208739
# Loss at iteratioin 1.038876972736651
# Loss at iteratioin 0.9033839097857164
# Loss at iteratioin 1.180417426327487
# Loss at iteratioin 1.1826178398133675
# Loss at iteratioin 0.7343491091011013
# Loss at iteratioin 1.0422162622064233
# Loss at iteratioin 0.8653119442383574
# Loss at iteratioin 0.8981992089437544
# Loss at iteratioin 0.9048647934781249
# Loss at iteratioin 0.7930593018863039
# Loss at iteratioin 1.0007492233198336
# Loss at iteratioin 1.038786708017587
# Loss at iteratioin 0.9031948741503611
# Loss at iteratioin 1.1803436412532347
# Loss at iteratioin 1.1826048805772442
# Loss at iteratioin 0.7341039116835575
# Loss at iteratioin 1.0421095445165298
# Loss at iteratioin 0.8651622047443855
# Loss at iteratioin 0.8979921313337714
# Loss at iteratioin 0.9046624239017713
# Loss at iteratioin 0.7928761401225572
# Loss at iteratioin 1.000530949687343
# Loss at iteratioin 1.0386940556230435
# Loss at iteratioin 0.9030062521229688
# Loss at iteratioin 1.1802678512950204
# Loss at iteratioin 1.1825901809080406
# Loss at iteratioin 0.7338602358181482
# Loss at iteratioin 1.0420024320254697
# Loss at iteratioin 0.8650128807601889
# Loss at iteratioin 0.8977850054999396
# Loss at iteratioin 0.9044608220390138
# Loss at iteratioin 0.7926934939702154
# Loss at iteratioin 1.0003144931117294
# Loss at iteratioin 1.0385991560504095
# Loss at iteratioin 0.9028180576330773
# Loss at iteratioin 1.1801901697483002
# Loss at iteratioin 1.1825737575255133
# Loss at iteratioin 0.7336180379346119
# Loss at iteratioin 1.0418949273587585
# Loss at iteratioin 0.8648639386987339
# Loss at iteratioin 0.897577876934146
# Loss at iteratioin 0.9042599503957179
# Loss at iteratioin 0.7925113700994526
# Loss at iteratioin 1.0000997884402
# Loss at iteratioin 1.0385021410297612
# Loss at iteratioin 0.9026303039379605
# Loss at iteratioin 1.1801107025474937
# Loss at iteratioin 1.1825556269944721
# Loss at iteratioin 0.7333772771104881
# Loss at iteratioin 1.0417870347252896
# Loss at iteratioin 0.8647153479569551
# Loss at iteratioin 0.8973707875441607
# Loss at iteratioin 0.9040597753774335
# Loss at iteratioin 0.792329773585297
# Loss at iteratioin 0.9998867736924284
# Loss at iteratioin 1.038403134109653
# Loss at iteratioin 0.9024430035371623
# Loss at iteratioin 1.1800295488569272
# Loss at iteratioin 1.182535805858329
# Loss at iteratioin 0.7331379148377704
# Loss at iteratioin 1.0416787595924606
# Loss at iteratioin 0.8645670807274184
# Loss at iteratioin 0.8971637759501165
# Loss at iteratioin 0.9038602668800317
# Loss at iteratioin 0.7921487080987837
# Loss at iteratioin 0.9996753898850399
# Loss at iteratioin 1.0383022512030675
# Loss at iteratioin 0.9022561681143909
# Loss at iteratioin 1.1799468016021193
# Loss at iteratioin 1.1825143107381528
# Loss at iteratioin 0.7328999148158589
# Loss at iteratioin 1.0415701084164128
# Loss at iteratioin 0.8644191118128891
# Loss at iteratioin 0.8969568777523652
# Loss at iteratioin 0.9036613979247097
# Loss at iteratioin 0.7919681760774695
# Loss at iteratioin 0.9994655808663998
# Loss at iteratioin 1.0381996010958978
# Loss at iteratioin 0.9020698085016532
# Loss at iteratioin 1.179862547948713
# Loss at iteratioin 1.1824911584044555
# Loss at iteratioin 0.7326632427672225
# Loss at iteratioin 1.0414610884183624
# Loss at iteratioin 0.8642714184456095
# Loss at iteratioin 0.8967501257740117
# Loss at iteratioin 0.9034631443321316
# Loss at iteratioin 0.7917881788773298
# Loss at iteratioin 0.9992572931611275
# Loss at iteratioin 1.038095285920318
# Loss at iteratioin 0.9018839346613494
# Loss at iteratioin 1.1797768697353173
# Loss at iteratioin 1.1824663658274432
# Loss at iteratioin 0.7324278662727556
# Loss at iteratioin 1.04135170739949
# Loss at iteratioin 0.864123980112635
# Loss at iteratioin 0.896543550280984
# Loss at iteratioin 0.9032654844311699
# Loss at iteratioin 0.7916087169079317
# Loss at iteratioin 0.999050475823778
# Loss at iteratioin 1.0379894015953355
# Loss at iteratioin 0.9016985556827531
# Loss at iteratioin 1.1796898438656782
# Loss at iteratioin 1.182439950210259
# Loss at iteratioin 0.7321937546242848
# Loss at iteratioin 1.041241973588096
# Loss at iteratioin 0.8639767783881893
# Loss at iteratioin 0.8963371791821105
# Loss at iteratioin 0.903068398798297
# Loss at iteratioin 0.7914297897526323
# Loss at iteratioin 0.9988450803011684
# Loss at iteratioin 1.0378820382367426
# Loss at iteratioin 0.9015136797898977
# Loss at iteratioin 1.1796015426648536
# Loss at iteratioin 1.1824119290088368
# Loss at iteratioin 0.7319608786920644
# Loss at iteratioin 1.0411318955137412
# Loss at iteratioin 0.8638297967737008
# Loss at iteratioin 0.896131038211361
# Loss at iteratioin 0.9028718700241783
# Loss at iteratioin 0.7912513962753845
# Loss at iteratioin 0.998641060302828
# train loss 0.8288225020600591
# valid loss 0.20856374616871126

# %%
#test the model
#apply evaluation metrics
log_loss=model.get_train_val_prediction()
plt.plot(log_loss['train_loss'])
plt.plot(log_loss['val_loss'])

# %%
plt.plot(model.losses)

# %% [markdown]
# **That much variation between the training and validation because the batch losses are taken as average accrss min batches**

# %%
train_loss = list(map(lambda x:x[0], model.train_loss))
valid_loss = list(map(lambda x: x[0], model.valid_loss))
folds = list(map(lambda x: x[1], model.train_loss))
df = pd.DataFrame({'train_loss':train_loss, 'valid_loss':valid_loss, 'folds':folds})
sns.jointplot(data = df , x = 'train_loss', y='valid_loss', hue = 'folds')
#plt.xlabel('Training loss')
#plt.ylabel('Validation loss')

# %% [markdown]
# **losses without average after model fits, here the loss is to show the model generalisation, for instance is the training loss is 0.8 accross all the validation losse, the fold 4 is having higher value the reason to that could be because we have taken last fold assuming that model gradient stop updating for last min batch, lets analyse other metrics to see the predictive performance of the model before we deply to mlflow**
#
# **<span style="color:blue">Probably in earlier assignments the model were predicting better of the latest data. The solution is stack all the theta value from the min batch and the perform prediction across the cross validation</span>**

# %%
pred=model.predict(test.values)
print('precision: {}'.format(precision_score(test_y.values, pred, average='macro')), 
      'recall: {}'.format(recall_score(test_y.values, pred, average='macro')))
# Out:
# precision: 0.646832116516427 recall: 0.6375250139912889

# %%
make_confusion_matrix(confusion_matrix(test_y.values, pred))

# %% [markdown]
# what does support in the classification report means?

# %%
#task to do
#precision recall, accuracy and confusion matrix and roc-auc curve
#apply ridgem with mlflow deplyoment
#add the model the web application
#CICD

# %%
import sys

def str_to_class(classname):
    return getattr(sys.modules[__name__],classname)

global _score 
_score = 0

# %%
#without replacement sample , because of memeory and computational issues.
train=train.sample(1000)
x_target = x_target.loc[train.index]
test = test.sample(670)
y_target = y_target.loc[test.index]
unscaled_train=unscaled_train.loc[train.index]
unscaled_test = unscaled_test.loc[test.index]

# %%
train['binned_engine']=train['binned_engine'].astype('category')
test['binned_engine'] = test['binned_engine'].astype('category')

# %% [markdown]
# **some encoding for linear regression previous model was non linear**

# %%
def train_validate(regs, params, function, per_eta, regularise = False):
    for reg in regs:
        #params = {"method": "batch", "lr":0.1, 'eta':0.003, 'regularization':None, '_names':feature_names}
        #mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}-eta-{params['eta']}", nested=True)
        mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}", nested=True)
        print("="*5, reg, "="*5)
        ########
        type_of_regression = str_to_class(reg)#Ridge, Lasso, ElasticNet
        #use params reg_ in order to run regularizers
        params['reg_'] = reg
        model = type_of_regression(**params)  
    
        
        scores = model.fit(train.values, x_target.values)
        yhat = model.predict(test.values)
        mse  = model.mse(ytrue = y_target, ypred = yhat)
        r_ = model.r_square(ytrue = y_target, ypred = yhat)
        if per_eta:
            function(scores, mse,r_ ,params['eta'])
        if regularise:
            coef = model._coef()
            function(scores, mse, r_, params ,coef=coef, model= model)
        else:
            function(scores, mse,r_, params)
            
            
        print("Test MSE: ", mse)
        mlflow.log_metric(key="test_mse", value=mse)

        signature = mlflow.models.infer_signature(train, model.predict(train))
        mlflow.sklearn.log_model(model, artifact_path='model', signature=signature)

    # #######
        mlflow.end_run()

# %% [markdown]
# **with momentum and without momentum**

# %%
#
scores_di = []
def f(scores, mse, r_,eta):
    scores_di.append((scores, mse, eta,r_))
#etas params
etas = [0.1, 0.9 , None]
params = {'method':'batch', 'lr':0.01, 'reg_':False,'regularization':False, 'eta':None, '_names':feature_names}
for eta in etas:
    params['eta'] = eta
    print('Momentum rate:', eta)
    train_validate(['LinearRegression'], params, f, per_eta = True)
        
# params = {"method":"batch", "lr":0.01, 'eta':None,'regularization':False, '_names':feature_names}
# scores = train_validate(['LinearRegression'], params, f, per_eta = False)

# %%
scores_di[0][3]

# %%
sns.set_theme()
fig, ax=plt.subplots(2,3, figsize=(20,10))
ax[0,0].plot(scores_di[0][0]['val_score'], label = 'Valid_MSE')
ax[0,0].plot(scores_di[0][0]['train_score'], label = 'Train_MSE')
ax[0,0].set_title('Momentum Value:{}'.format(scores_di[0][2]))
ax[0,0].legend()


ax[0,1].plot(scores_di[2][0]['val_score'], label = 'Validation_MSE')
ax[0,1].plot(scores_di[2][0]['train_score'], label = 'Train_MSE')
ax[0,1].set_title('Momentum Value:{}'.format(scores_di[2][2]))
ax[0,1].legend()

ax[0,2].plot(scores_di[4][0]['val_score'], label = 'Validation_MSE')
ax[0,2].plot(scores_di[4][0]['train_score'], label = 'Train_MSE')
ax[0,2].set_title('Momentum Value:{}'.format(scores_di[4][2]))
ax[0,2].legend()


ax[1,0].plot(scores_di[0][0]['r_sq_val'], label = 'Validation_r^2')
ax[1,0].plot(scores_di[0][0]['r_sq_train'], label = 'Train_r^2')
ax[1,0].set_title('Momentum Value:{}'.format(scores_di[0][2]))
ax[1,0].legend()

ax[1,1].plot(scores_di[2][0]['r_sq_val'], label='Validation_r^2')
ax[1,1].plot(scores_di[2][0]['r_sq_train'], label ='Train_r^2')
ax[1,1].set_title('Momentum Value:{}'.format(scores_di[2][2]))
ax[1,1].legend()

ax[1,2].plot(scores_di[4][0]['r_sq_val'], label = 'Validation_r^2')
ax[1,2].plot(scores_di[4][0]['r_sq_train'], label = 'Train_r^2')
ax[1,2].set_title('Momentum Value:{}'.format(scores_di[4][2]))
ax[1,2].legend()
